# %% [markdown]
# # Starting point

# %%
import sys
import pandas as pd

sys.path.append('./modules')
from modules import composition, comp_func
from modules.functional import specification, generalisation, information_quantity

from transformers import AutoModel, AutoTokenizer, pipeline

import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import seaborn as sns

# %%
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Uncomment if you know your GPU doesn't have enough memory
# device = 'cpu'

model_name = 'bert-base-cased'
model = AutoModel.from_pretrained(model_name, device_map=device)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
projection = pipeline('composition', model=model, tokenizer=tokenizer)

# %% [markdown]
# ## Former code

# %%
def test_property(logic_value):
  if logic_value:
    return 1
  else:
    return 0

# %%
import torch
def similarity(vector_1, vector_2, sim_fun):
  if sim_fun == 1:
    scalar_product = torch.dot(vector_1, vector_2)
    squared_module_1 = torch.dot(vector_1, vector_1)
    squared_module_2 = torch.dot(vector_2, vector_2)
    cosine = scalar_product / (squared_module_1 * squared_module_2)
    return cosine

  elif sim_fun == 2:
    return torch.norm(vector_1 - vector_2)

  elif sim_fun == 3:
    return torch.dot(vector_1, vector_2)

  elif sim_fun == 4:
    inf_quant_12 = information_quantity(vector_1) + information_quantity(vector_2) - torch.dot(vector_1, vector_2)
    return information_quantity(vector_1) + information_quantity(vector_2) - 1.5 * inf_quant_12

  elif sim_fun == 5:
    inf_quant_12 = information_quantity(vector_1) + information_quantity(vector_2) - torch.dot(vector_1, vector_2)
    if information_quantity(vector_1) >= information_quantity(vector_2):
      alpha_1 = 1.5
      alpha_2 = 0.5
    else:
      alpha_1 = 0.5
      alpha_2 = 1.5
    beta = 1.5
    return alpha_1 * information_quantity(vector_1) + alpha_2 * information_quantity(vector_2) - beta * inf_quant_12

  elif sim_fun == 6:
    inf_quant_12 = information_quantity(vector_1) + information_quantity(vector_2) - torch.dot(vector_1, vector_2)
    if information_quantity(vector_1) >= information_quantity(vector_2):
      alpha_1 = 1.75
      alpha_2 = 0.75
    else:
      alpha_1 = 0.75
      alpha_2 = 1.75
    beta = 1.5
    return alpha_1 * information_quantity(vector_1) + alpha_2 * information_quantity(vector_2) - beta * inf_quant_12

  elif sim_fun == 7:
    inf_quant_12 = information_quantity(vector_1) + information_quantity(vector_2) - torch.dot(vector_1, vector_2)
    if information_quantity(vector_1) >= information_quantity(vector_2):
      alpha_1 = 1.5
      alpha_2 = 0.5
    else:
      alpha_1 = 0.5
      alpha_2 = 1.5
    beta = 1
    return alpha_1 * information_quantity(vector_1) + alpha_2 * information_quantity(vector_2) - beta * inf_quant_12

  elif sim_fun == 8:
    inf_quant_12 = information_quantity(vector_1) + information_quantity(vector_2) - torch.dot(vector_1, vector_2)
    if information_quantity(vector_1) >= information_quantity(vector_2):
      alpha_1 = 1.5
      alpha_2 = 0.5
    else:
      alpha_1 = 0.5
      alpha_2 = 1.5
    beta = 2
    return alpha_1 * information_quantity(vector_1) + alpha_2 * information_quantity(vector_2) - beta * inf_quant_12

  elif sim_fun == 9:
    inf_quant_12 = information_quantity(vector_1) + information_quantity(vector_2) - torch.dot(vector_1, vector_2)
    if information_quantity(vector_1) >= information_quantity(vector_2):
      alpha_1 = 0.5
      alpha_2 = 1.5
    else:
      alpha_1 = 1.5
      alpha_2 = 0.5
    beta = 1.5
    return alpha_1 * information_quantity(vector_1) + alpha_2 * information_quantity(vector_2) - beta * inf_quant_12

  elif sim_fun == 10:
    inf_quant_12 = information_quantity(vector_1) + information_quantity(vector_2) - torch.dot(vector_1, vector_2)
    if information_quantity(vector_1) >= information_quantity(vector_2):
      alpha_1 = 0.5
      alpha_2 = 1.5
    else:
      alpha_1 = 1.5
      alpha_2 = 0.5
    beta = 0.5
    return alpha_1 * information_quantity(vector_1) + alpha_2 * information_quantity(vector_2) - beta * inf_quant_12

  elif sim_fun == 11:
    inf_quant_12 = information_quantity(vector_1) + information_quantity(vector_2) - torch.dot(vector_1, vector_2)
    if information_quantity(vector_1) >= information_quantity(vector_2):
      alpha_1 = 1.5
      alpha_2 = 1
    else:
      alpha_1 = 1
      alpha_2 = 1.5
    beta = 1.5
    return alpha_1 * information_quantity(vector_1) + alpha_2 * information_quantity(vector_2) - beta * inf_quant_12

# %% [markdown]
# # definition

# %%
rows = ['Constraint 1 - Injectivity', 'Constraint 2 - Zero informativeness', 'Constraint 3 - Infinite informativeness', 'Constraint 4 - Upper and lower bounds',
        'Constraint 5 - Commutativity', 'Constraint 6 - Associativity', 'Constraint 7 - Distributiveness', 'Constraint 8 - Idempotency',
        'Constraint 9 - Identity', 'Constraint 10 - Similarity monotonicity', 'Constraint 11 - Self-similarity', 'Constraint 12 - Asymmetricity', 'Constraint 1 - Injectivity', 'Constraint 2 - Zero informativeness', 'Constraint 3 - Infinite informativeness', 'Constraint 4 - Upper and lower bounds',
        'Constraint 5 - Commutativity', 'Constraint 6 - Associativity', 'Constraint 7 - Distributiveness', 'Constraint 8 - Idempotency',
        'Constraint 9 - Identity', 'Constraint 10 - Similarity monotonicity', 'Constraint 11 - Self-similarity', 'Constraint 12 - Asymmetricity', 'Constraint 1 - Injectivity', 'Constraint 2 - Zero informativeness', 'Constraint 3 - Infinite informativeness', 'Constraint 4 - Upper and lower bounds',
        'Constraint 5 - Commutativity', 'Constraint 6 - Associativity', 'Constraint 7 - Distributiveness', 'Constraint 8 - Idempotency',
        'Constraint 9 - Identity', 'Constraint 10 - Similarity monotonicity', 'Constraint 11 - Self-similarity', 'Constraint 12 - Asymmetricity']

columns = []
for embed in ['Sum of Vectors', 'Average', 'F_joint', 'F_ind', 'F_inf']: #embedding
  for spec_gen in ['Algebraic','Information','Fuzzy']: #spec and gen functions
    for similarity_function in ['Cosine','Euclidean','Dot','ICM_100_100_150','ICM_150_050_150','ICM_175_075_15','ICM_150_050_100','ICM_150_050_200','ICM_050_150_150','ICM_050_150_050','ICM_150_100_150']: #similarity

      columns.append(embed + " - " + spec_gen + " - " + similarity_function)

results = pd.DataFrame(0, index=rows, columns=columns)

# %%
sequences = pd.read_excel('./datasets/sequences.xlsx')
ancestors = pd.read_excel('./datasets/ancestors.xlsx')
summaries = pd.read_excel('./datasets/summaries.xlsx')

# %%
information_quantity(projection(' ', comp_fun='inf'))
# Out:
# tensor(0.)

# %% [markdown]
# # word sequences

# %%
print('Progress: 0%')

q = 0
m = -1
for k in ['sum', 'avg', 'jnt', 'ind', 'inf']: #embedding
  for h in range (3): #spec and gen functions
    h += 1
    for j in range(11): #similarity
      j += 1
      m += 1

      for i in range(len(sequences)):
        q += 1
        vectors = [sequences.iloc[i][0], sequences.iloc[i][1], sequences.iloc[i][2]]
        vectors.sort()

        text_1 = vectors[2]
        text_2 = vectors[1]
        text_3 = vectors[0]

        # given text_1, text_2, text_3
        vector_1 = projection(text_1, comp_fun = k)
        vector_2 = projection(text_2, comp_fun = k)
        vector_3 = projection(text_3, comp_fun = k)
        vector_12 = projection(text_1 + " " + text_2, comp_fun = k)
        vector_123 = projection(text_1 + " " + text_2 + " " + text_3, comp_fun = k)

        # Test 1
        results.iloc[0][m] += test_property(information_quantity(vector_1) != information_quantity(vector_2))

        # Test 2
        results.iloc[1][m] += test_property(information_quantity(projection(" ", comp_fun = k)) == 0)

        # Test 18
        results.iloc[2][m] += test_property(information_quantity(vector_1) < information_quantity(vector_12))

        # Test 19
        results.iloc[3][m] += test_property((information_quantity(vector_1) < information_quantity(specification(vector_1, vector_2, h)) and information_quantity(vector_2) < information_quantity(specification(vector_1, vector_2, h))))

        # Test 20
        results.iloc[3][m] += test_property((information_quantity(vector_1) > information_quantity(generalisation(vector_1, vector_2, h)) and information_quantity(vector_2) > information_quantity(generalisation(vector_1, vector_2, h))))

        # Test 3
        results.iloc[4][m] += test_property((specification(vector_1, vector_2, h) == specification(vector_2, vector_1, h)).all())

        # Test 4
        results.iloc[4][m] += test_property((generalisation(vector_1, vector_2, h) == generalisation(vector_2, vector_1, h)).all())

        # Test 5
        results.iloc[5][m] += test_property((specification(specification(vector_1, vector_2, h), vector_3, h) == specification(vector_1, specification(vector_2, vector_3, h), h)).all())

        # Test 6
        results.iloc[5][m] += test_property((generalisation(generalisation(vector_1, vector_2, h), vector_3, h) == generalisation(vector_1, generalisation(vector_2, vector_3, h), h)).all())

        # Test 7
        results.iloc[6][m] += test_property((specification(generalisation(vector_1, vector_2, h), vector_3, h) == specification(vector_1, generalisation(vector_2, vector_3, h), h)).all())

        # Test 8
        results.iloc[6][m] += test_property((generalisation(specification(vector_1, vector_2, h), vector_3, h) == generalisation(vector_1, specification(vector_2, vector_3, h), h)).all())

        # Test 9
        results.iloc[7][m] += test_property(similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h) , generalisation(vector_1, vector_2, h), j) > similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h) , generalisation(generalisation(vector_1, vector_2, h), vector_3, h), j))

        # Test 10
        results.iloc[7][m] += test_property(similarity(specification(specification(vector_1, vector_2, h), vector_2, h) , specification(vector_1, vector_2, h), j) > similarity(specification(specification(vector_1, vector_2, h), vector_2, h) , specification(specification(vector_1, vector_2, h), vector_3, h), j))

        # Test 11
        results.iloc[8][m] += test_property(similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h) , vector_1, j) > similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h) , vector_2, j))

        # Test 12
        results.iloc[8][m] += test_property(similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h) , vector_1, j) > similarity(specification(specification(vector_1, vector_2, h), vector_1, h) , vector_2, j))

        # Test 13
        results.iloc[9][m] += test_property(similarity(specification(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))

        # Test 14
        results.iloc[9][m] += test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))

        # Test 15
        results.iloc[10][m] += test_property(similarity(vector_1, vector_1, j) > similarity(vector_2, vector_2, j))

        # Test 16
        results.iloc[11][m] += test_property(similarity(vector_1, specification(vector_1, vector_2, h), j) < similarity(specification(vector_1, vector_2, h), vector_1, j))

        # Test 17
        results.iloc[11][m] += test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) < similarity(vector_1, generalisation(vector_1, vector_2, h), j))

        if q % 750 == 0:
          print('Progress: ' + str(round(q *100 /(len(sequences) * 165),2)) + '%')
print('Progress: 100%!')
# Out:
# Progress: 0%
# /tmp/ipykernel_98198/3275942573.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   vectors = [sequences.iloc[i][0], sequences.iloc[i][1], sequences.iloc[i][2]]
# /tmp/ipykernel_98198/3275942573.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[0][m] += test_property(information_quantity(vector_1) != information_quantity(vector_2))
# /tmp/ipykernel_98198/3275942573.py:29: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[0][m] += test_property(information_quantity(vector_1) != information_quantity(vector_2))
# /tmp/ipykernel_98198/3275942573.py:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[1][m] += test_property(information_quantity(projection(" ", comp_fun = k)) == 0)
# /tmp/ipykernel_98198/3275942573.py:32: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[1][m] += test_property(information_quantity(projection(" ", comp_fun = k)) == 0)
# /tmp/ipykernel_98198/3275942573.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[2][m] += test_property(information_quantity(vector_1) < information_quantity(vector_12))
# /tmp/ipykernel_98198/3275942573.py:35: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[2][m] += test_property(information_quantity(vector_1) < information_quantity(vector_12))
# /tmp/ipykernel_98198/3275942573.py:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[3][m] += test_property((information_quantity(vector_1) < information_quantity(specification(vector_1, vector_2, h)) and information_quantity(vector_2) < information_quantity(specification(vector_1, vector_2, h))))
# /tmp/ipykernel_98198/3275942573.py:38: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[3][m] += test_property((information_quantity(vector_1) < information_quantity(specification(vector_1, vector_2, h)) and information_quantity(vector_2) < information_quantity(specification(vector_1, vector_2, h))))
# /tmp/ipykernel_98198/3275942573.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[3][m] += test_property((information_quantity(vector_1) > information_quantity(generalisation(vector_1, vector_2, h)) and information_quantity(vector_2) > information_quantity(generalisation(vector_1, vector_2, h))))
# /tmp/ipykernel_98198/3275942573.py:41: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[3][m] += test_property((information_quantity(vector_1) > information_quantity(generalisation(vector_1, vector_2, h)) and information_quantity(vector_2) > information_quantity(generalisation(vector_1, vector_2, h))))
# /tmp/ipykernel_98198/3275942573.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[4][m] += test_property((specification(vector_1, vector_2, h) == specification(vector_2, vector_1, h)).all())
# /tmp/ipykernel_98198/3275942573.py:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[4][m] += test_property((specification(vector_1, vector_2, h) == specification(vector_2, vector_1, h)).all())
# /tmp/ipykernel_98198/3275942573.py:47: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[4][m] += test_property((generalisation(vector_1, vector_2, h) == generalisation(vector_2, vector_1, h)).all())
# /tmp/ipykernel_98198/3275942573.py:47: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[4][m] += test_property((generalisation(vector_1, vector_2, h) == generalisation(vector_2, vector_1, h)).all())
# /tmp/ipykernel_98198/3275942573.py:50: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[5][m] += test_property((specification(specification(vector_1, vector_2, h), vector_3, h) == specification(vector_1, specification(vector_2, vector_3, h), h)).all())
# /tmp/ipykernel_98198/3275942573.py:50: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[5][m] += test_property((specification(specification(vector_1, vector_2, h), vector_3, h) == specification(vector_1, specification(vector_2, vector_3, h), h)).all())
# /tmp/ipykernel_98198/3275942573.py:53: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[5][m] += test_property((generalisation(generalisation(vector_1, vector_2, h), vector_3, h) == generalisation(vector_1, generalisation(vector_2, vector_3, h), h)).all())
# /tmp/ipykernel_98198/3275942573.py:53: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[5][m] += test_property((generalisation(generalisation(vector_1, vector_2, h), vector_3, h) == generalisation(vector_1, generalisation(vector_2, vector_3, h), h)).all())
# /tmp/ipykernel_98198/3275942573.py:56: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[6][m] += test_property((specification(generalisation(vector_1, vector_2, h), vector_3, h) == specification(vector_1, generalisation(vector_2, vector_3, h), h)).all())
# /tmp/ipykernel_98198/3275942573.py:56: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[6][m] += test_property((specification(generalisation(vector_1, vector_2, h), vector_3, h) == specification(vector_1, generalisation(vector_2, vector_3, h), h)).all())
# /tmp/ipykernel_98198/3275942573.py:59: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[6][m] += test_property((generalisation(specification(vector_1, vector_2, h), vector_3, h) == generalisation(vector_1, specification(vector_2, vector_3, h), h)).all())
# /tmp/ipykernel_98198/3275942573.py:59: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[6][m] += test_property((generalisation(specification(vector_1, vector_2, h), vector_3, h) == generalisation(vector_1, specification(vector_2, vector_3, h), h)).all())
# /tmp/ipykernel_98198/3275942573.py:62: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[7][m] += test_property(similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h) , generalisation(vector_1, vector_2, h), j) > similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h) , generalisation(generalisation(vector_1, vector_2, h), vector_3, h), j))
# /tmp/ipykernel_98198/3275942573.py:62: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[7][m] += test_property(similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h) , generalisation(vector_1, vector_2, h), j) > similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h) , generalisation(generalisation(vector_1, vector_2, h), vector_3, h), j))
# /tmp/ipykernel_98198/3275942573.py:65: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[7][m] += test_property(similarity(specification(specification(vector_1, vector_2, h), vector_2, h) , specification(vector_1, vector_2, h), j) > similarity(specification(specification(vector_1, vector_2, h), vector_2, h) , specification(specification(vector_1, vector_2, h), vector_3, h), j))
# /tmp/ipykernel_98198/3275942573.py:65: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[7][m] += test_property(similarity(specification(specification(vector_1, vector_2, h), vector_2, h) , specification(vector_1, vector_2, h), j) > similarity(specification(specification(vector_1, vector_2, h), vector_2, h) , specification(specification(vector_1, vector_2, h), vector_3, h), j))
# /tmp/ipykernel_98198/3275942573.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[8][m] += test_property(similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h) , vector_1, j) > similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h) , vector_2, j))
# /tmp/ipykernel_98198/3275942573.py:68: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[8][m] += test_property(similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h) , vector_1, j) > similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h) , vector_2, j))
# /tmp/ipykernel_98198/3275942573.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[8][m] += test_property(similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h) , vector_1, j) > similarity(specification(specification(vector_1, vector_2, h), vector_1, h) , vector_2, j))
# /tmp/ipykernel_98198/3275942573.py:71: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[8][m] += test_property(similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h) , vector_1, j) > similarity(specification(specification(vector_1, vector_2, h), vector_1, h) , vector_2, j))
# /tmp/ipykernel_98198/3275942573.py:74: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[9][m] += test_property(similarity(specification(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))
# /tmp/ipykernel_98198/3275942573.py:74: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[9][m] += test_property(similarity(specification(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))
# /tmp/ipykernel_98198/3275942573.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[9][m] += test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))
# /tmp/ipykernel_98198/3275942573.py:77: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[9][m] += test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))
# /tmp/ipykernel_98198/3275942573.py:80: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[10][m] += test_property(similarity(vector_1, vector_1, j) > similarity(vector_2, vector_2, j))
# /tmp/ipykernel_98198/3275942573.py:80: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[10][m] += test_property(similarity(vector_1, vector_1, j) > similarity(vector_2, vector_2, j))
# /tmp/ipykernel_98198/3275942573.py:83: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[11][m] += test_property(similarity(vector_1, specification(vector_1, vector_2, h), j) < similarity(specification(vector_1, vector_2, h), vector_1, j))
# /tmp/ipykernel_98198/3275942573.py:83: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[11][m] += test_property(similarity(vector_1, specification(vector_1, vector_2, h), j) < similarity(specification(vector_1, vector_2, h), vector_1, j))
# /tmp/ipykernel_98198/3275942573.py:86: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[11][m] += test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) < similarity(vector_1, generalisation(vector_1, vector_2, h), j))
# /tmp/ipykernel_98198/3275942573.py:86: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[11][m] += test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) < similarity(vector_1, generalisation(vector_1, vector_2, h), j))
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Progress: 4.55%
# Progress: 9.09%
# Progress: 13.64%
# Progress: 18.18%
# Progress: 22.73%
# Progress: 27.27%
# Progress: 31.82%
# Progress: 36.36%
# Progress: 40.91%
# Progress: 45.45%
# Progress: 50.0%
# Progress: 54.55%
# Progress: 59.09%
# Progress: 63.64%
# Progress: 68.18%
# Progress: 72.73%
# Progress: 77.27%
# Progress: 81.82%
# Progress: 86.36%
# Progress: 90.91%
# Progress: 95.45%
# Progress: 100.0%
# Progress: 100%!

# %% [markdown]
# # ancestors

# %%
print('Progress: 0%')

q = 0
m = -1
for k in ['sum', 'avg', 'jnt', 'ind', 'inf']: #embedding
  for h in range (3): #spec and gen functions
    h += 1
    for j in range(11): #similarity
      j += 1
      m += 1
      for i in range(len(ancestors)):
        q += 1
        text_1 = ancestors.iloc[i][0] # w
        text_1b = ancestors.iloc[i][1] # w'
        text_2 = ancestors.iloc[i][2] # ancestor w_a
        text_3 = ancestors.iloc[i][3] # ancestor w_aa

        # given text_1, text_2, text_3
        vector_1 = projection(text_1, comp_fun = k)
        vector_1b = projection(text_1b, comp_fun = k)
        vector_2 = projection(text_2, comp_fun = k)
        vector_3 = projection(text_3, comp_fun = k)
        vector_n = projection('cheese',comp_fun = k)

        # Test 1
        results.iloc[12][m] += test_property(information_quantity(vector_1) != information_quantity(vector_2))

        # Test 2
        results.iloc[13][m] += test_property(information_quantity(projection(" ",comp_fun = k)) == 0)

        # Test 21
        results.iloc[14][m] += test_property(information_quantity(vector_2) != information_quantity(vector_1))

        # Test 22
        results.iloc[15][m] += test_property(information_quantity(generalisation(vector_1,vector_2, h)) < information_quantity(generalisation(vector_1,vector_n, h)))

        # Test 23
        results.iloc[15][m] += test_property(information_quantity(specification(vector_1,vector_2, h)) > information_quantity(specification(vector_1,vector_n, h)))

        # Test 3
        results.iloc[16][m] += test_property((specification(vector_1, vector_2, h) == specification(vector_2, vector_1, h)).all())

        # Test 4
        results.iloc[16][m] += test_property((generalisation(vector_1, vector_2, h) == generalisation(vector_2, vector_1, h)).all())

        # Test 5
        results.iloc[17][m] += test_property((specification(specification(vector_1, vector_2, h), vector_1b, h) == specification(vector_1, specification(vector_2, vector_1b, h), h)).all())

        # Test 6
        results.iloc[17][m] += test_property((generalisation(generalisation(vector_1, vector_2, h), vector_1b, h) == generalisation(vector_1, generalisation(vector_2, vector_1b, h), h)).all())

        # Test 7
        results.iloc[18][m] += test_property((specification(generalisation(vector_1, vector_2, h), vector_1b, h) == specification(vector_1, generalisation(vector_2, vector_1b, h), h)).all())

        # Test 8
        results.iloc[18][m] += test_property((generalisation(specification(vector_1, vector_2, h), vector_1b, h) == generalisation(vector_1, specification(vector_2, vector_1b, h), h)).all())

        # Test 9
        results.iloc[19][m] += test_property(similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h), generalisation(vector_1, vector_2, h), j) > similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h) , generalisation(generalisation(vector_1, vector_2, h), vector_3, h), j))

        # Test 10
        results.iloc[19][m] += test_property(similarity(specification(specification(vector_1, vector_2, h), vector_2, h), specification(vector_1, vector_2, h), j) > similarity(specification(specification(vector_1, vector_2, h), vector_2, h) , specification(specification(vector_1, vector_2, h), vector_3, h), j))

        # Test 11
        results.iloc[20][m] += test_property(similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h), vector_1, j) > similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h) , vector_2, j))

        # Test 12
        results.iloc[20][m] += test_property(similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h), vector_1, j) > similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h) , vector_2, j))

        # Test 13
        results.iloc[21][m] += test_property(similarity(specification(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))

        # Test 14
        results.iloc[21][m] += test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))

        # Test 15
        results.iloc[22][m] += test_property(similarity(vector_1, vector_1, j) > similarity(vector_2, vector_2, j))

        # Test 16
        results.iloc[23][m] += test_property(similarity(vector_1, specification(vector_1, vector_2, h), j) < similarity(specification(vector_1, vector_2, h), vector_1, j))

        # Test 17
        results.iloc[23][m] += test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) < similarity(vector_1, generalisation(vector_1, vector_2, h), j))

        if q % 386 == 0:
          print('Progress: ' + str(round(q *100 /(len(ancestors) * 165),2)) + '%')
print('Progress: 100%!')
# Out:
# Progress: 0%
# /tmp/ipykernel_98198/1920367870.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text_1 = ancestors.iloc[i][0] # w
# /tmp/ipykernel_98198/1920367870.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text_1b = ancestors.iloc[i][1] # w'
# /tmp/ipykernel_98198/1920367870.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text_2 = ancestors.iloc[i][2] # ancestor w_a
# /tmp/ipykernel_98198/1920367870.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text_3 = ancestors.iloc[i][3] # ancestor w_aa
# /tmp/ipykernel_98198/1920367870.py:26: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[12][m] += test_property(information_quantity(vector_1) != information_quantity(vector_2))
# /tmp/ipykernel_98198/1920367870.py:26: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[12][m] += test_property(information_quantity(vector_1) != information_quantity(vector_2))
# /tmp/ipykernel_98198/1920367870.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[13][m] += test_property(information_quantity(projection(" ",comp_fun = k)) == 0)
# /tmp/ipykernel_98198/1920367870.py:29: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[13][m] += test_property(information_quantity(projection(" ",comp_fun = k)) == 0)
# /tmp/ipykernel_98198/1920367870.py:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[14][m] += test_property(information_quantity(vector_2) != information_quantity(vector_1))
# /tmp/ipykernel_98198/1920367870.py:32: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[14][m] += test_property(information_quantity(vector_2) != information_quantity(vector_1))
# /tmp/ipykernel_98198/1920367870.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[15][m] += test_property(information_quantity(generalisation(vector_1,vector_2, h)) < information_quantity(generalisation(vector_1,vector_n, h)))
# /tmp/ipykernel_98198/1920367870.py:35: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[15][m] += test_property(information_quantity(generalisation(vector_1,vector_2, h)) < information_quantity(generalisation(vector_1,vector_n, h)))
# /tmp/ipykernel_98198/1920367870.py:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[15][m] += test_property(information_quantity(specification(vector_1,vector_2, h)) > information_quantity(specification(vector_1,vector_n, h)))
# /tmp/ipykernel_98198/1920367870.py:38: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[15][m] += test_property(information_quantity(specification(vector_1,vector_2, h)) > information_quantity(specification(vector_1,vector_n, h)))
# /tmp/ipykernel_98198/1920367870.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[16][m] += test_property((specification(vector_1, vector_2, h) == specification(vector_2, vector_1, h)).all())
# /tmp/ipykernel_98198/1920367870.py:41: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[16][m] += test_property((specification(vector_1, vector_2, h) == specification(vector_2, vector_1, h)).all())
# /tmp/ipykernel_98198/1920367870.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[16][m] += test_property((generalisation(vector_1, vector_2, h) == generalisation(vector_2, vector_1, h)).all())
# /tmp/ipykernel_98198/1920367870.py:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[16][m] += test_property((generalisation(vector_1, vector_2, h) == generalisation(vector_2, vector_1, h)).all())
# /tmp/ipykernel_98198/1920367870.py:47: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[17][m] += test_property((specification(specification(vector_1, vector_2, h), vector_1b, h) == specification(vector_1, specification(vector_2, vector_1b, h), h)).all())
# /tmp/ipykernel_98198/1920367870.py:47: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[17][m] += test_property((specification(specification(vector_1, vector_2, h), vector_1b, h) == specification(vector_1, specification(vector_2, vector_1b, h), h)).all())
# /tmp/ipykernel_98198/1920367870.py:50: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[17][m] += test_property((generalisation(generalisation(vector_1, vector_2, h), vector_1b, h) == generalisation(vector_1, generalisation(vector_2, vector_1b, h), h)).all())
# /tmp/ipykernel_98198/1920367870.py:50: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[17][m] += test_property((generalisation(generalisation(vector_1, vector_2, h), vector_1b, h) == generalisation(vector_1, generalisation(vector_2, vector_1b, h), h)).all())
# /tmp/ipykernel_98198/1920367870.py:53: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[18][m] += test_property((specification(generalisation(vector_1, vector_2, h), vector_1b, h) == specification(vector_1, generalisation(vector_2, vector_1b, h), h)).all())
# /tmp/ipykernel_98198/1920367870.py:53: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[18][m] += test_property((specification(generalisation(vector_1, vector_2, h), vector_1b, h) == specification(vector_1, generalisation(vector_2, vector_1b, h), h)).all())
# /tmp/ipykernel_98198/1920367870.py:56: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[18][m] += test_property((generalisation(specification(vector_1, vector_2, h), vector_1b, h) == generalisation(vector_1, specification(vector_2, vector_1b, h), h)).all())
# /tmp/ipykernel_98198/1920367870.py:56: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[18][m] += test_property((generalisation(specification(vector_1, vector_2, h), vector_1b, h) == generalisation(vector_1, specification(vector_2, vector_1b, h), h)).all())
# /tmp/ipykernel_98198/1920367870.py:59: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[19][m] += test_property(similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h), generalisation(vector_1, vector_2, h), j) > similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h) , generalisation(generalisation(vector_1, vector_2, h), vector_3, h), j))
# /tmp/ipykernel_98198/1920367870.py:59: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[19][m] += test_property(similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h), generalisation(vector_1, vector_2, h), j) > similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h) , generalisation(generalisation(vector_1, vector_2, h), vector_3, h), j))
# /tmp/ipykernel_98198/1920367870.py:62: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[19][m] += test_property(similarity(specification(specification(vector_1, vector_2, h), vector_2, h), specification(vector_1, vector_2, h), j) > similarity(specification(specification(vector_1, vector_2, h), vector_2, h) , specification(specification(vector_1, vector_2, h), vector_3, h), j))
# /tmp/ipykernel_98198/1920367870.py:62: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[19][m] += test_property(similarity(specification(specification(vector_1, vector_2, h), vector_2, h), specification(vector_1, vector_2, h), j) > similarity(specification(specification(vector_1, vector_2, h), vector_2, h) , specification(specification(vector_1, vector_2, h), vector_3, h), j))
# /tmp/ipykernel_98198/1920367870.py:65: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[20][m] += test_property(similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h), vector_1, j) > similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h) , vector_2, j))
# /tmp/ipykernel_98198/1920367870.py:65: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[20][m] += test_property(similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h), vector_1, j) > similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h) , vector_2, j))
# /tmp/ipykernel_98198/1920367870.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[20][m] += test_property(similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h), vector_1, j) > similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h) , vector_2, j))
# /tmp/ipykernel_98198/1920367870.py:68: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[20][m] += test_property(similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h), vector_1, j) > similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h) , vector_2, j))
# /tmp/ipykernel_98198/1920367870.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[21][m] += test_property(similarity(specification(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))
# /tmp/ipykernel_98198/1920367870.py:71: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[21][m] += test_property(similarity(specification(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))
# /tmp/ipykernel_98198/1920367870.py:74: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[21][m] += test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))
# /tmp/ipykernel_98198/1920367870.py:74: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[21][m] += test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))
# /tmp/ipykernel_98198/1920367870.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[22][m] += test_property(similarity(vector_1, vector_1, j) > similarity(vector_2, vector_2, j))
# /tmp/ipykernel_98198/1920367870.py:77: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[22][m] += test_property(similarity(vector_1, vector_1, j) > similarity(vector_2, vector_2, j))
# /tmp/ipykernel_98198/1920367870.py:80: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[23][m] += test_property(similarity(vector_1, specification(vector_1, vector_2, h), j) < similarity(specification(vector_1, vector_2, h), vector_1, j))
# /tmp/ipykernel_98198/1920367870.py:80: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[23][m] += test_property(similarity(vector_1, specification(vector_1, vector_2, h), j) < similarity(specification(vector_1, vector_2, h), vector_1, j))
# /tmp/ipykernel_98198/1920367870.py:83: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[23][m] += test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) < similarity(vector_1, generalisation(vector_1, vector_2, h), j))
# /tmp/ipykernel_98198/1920367870.py:83: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[23][m] += test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) < similarity(vector_1, generalisation(vector_1, vector_2, h), j))
# Progress: 2.34%
# Progress: 4.68%
# Progress: 7.02%
# Progress: 9.36%
# Progress: 11.7%
# Progress: 14.04%
# Progress: 16.38%
# Progress: 18.72%
# Progress: 21.05%
# Progress: 23.39%
# Progress: 25.73%
# Progress: 28.07%
# Progress: 30.41%
# Progress: 32.75%
# Progress: 35.09%
# Progress: 37.43%
# Progress: 39.77%
# Progress: 42.11%
# Progress: 44.45%
# Progress: 46.79%
# Progress: 49.13%
# Progress: 51.47%
# Progress: 53.81%
# Progress: 56.15%
# Progress: 58.48%
# Progress: 60.82%
# Progress: 63.16%
# Progress: 65.5%
# Progress: 67.84%
# Progress: 70.18%
# Progress: 72.52%
# Progress: 74.86%
# Progress: 77.2%
# Progress: 79.54%
# Progress: 81.88%
# Progress: 84.22%
# Progress: 86.56%
# Progress: 88.9%
# Progress: 91.24%
# Progress: 93.58%
# Progress: 95.92%
# Progress: 98.25%
# Progress: 100%!

# %% [markdown]
# # summaries

# %%
print('Progress: 0%')

q = 0
m = -1
for k in ['sum', 'avg', 'jnt', 'ind', 'inf']: #embedding
  for h in range (3): #spec and gen functions
    h += 1
    for j in range(11): #similarity
      j += 1
      m += 1
      for i in range(len(summaries)):
        q += 1
        text_1 = summaries.iloc[i][0] # r
        text_2 = summaries.iloc[i][1] # r_1
        text_3 = summaries.iloc[i][2] # r_2

        # given text_1, text_2, text_3
        vector_1 = projection(text_1, comp_fun = k)
        vector_2 = projection(text_2, comp_fun = k)
        vector_3 = projection(text_3, comp_fun = k)

        # Test 1
        results.iloc[24][m] += test_property(information_quantity(vector_1) != information_quantity(vector_2))

        # Test 2
        results.iloc[25][m] += test_property(information_quantity(projection(" ", comp_fun = k)) == 0)

        # Test 24
        results.iloc[26][m] += test_property(information_quantity(vector_2) < information_quantity(vector_1))

        # Test 25
        results.iloc[27][m] += test_property((information_quantity(vector_1) < information_quantity(specification(vector_1, vector_2, h)) and information_quantity(vector_2) < information_quantity(specification(vector_1, vector_2, h))))

        # Test 26
        results.iloc[27][m] += test_property((information_quantity(vector_1) > information_quantity(generalisation(vector_1, vector_2, h)) and information_quantity(vector_2) > information_quantity(generalisation(vector_1, vector_2, h))))

        # Test 3
        results.iloc[28][m] += test_property((specification(vector_1, vector_2, h) == specification(vector_2, vector_1, h)).all())

        # Test 4
        results.iloc[28][m] += test_property((generalisation(vector_1, vector_2, h) == generalisation(vector_2, vector_1, h)).all())

        # Test 5
        results.iloc[29][m] += test_property((specification(specification(vector_1, vector_2, h), vector_1b, h) == specification(vector_1, specification(vector_2, vector_1b, h), h)).all())

        # Test 6
        results.iloc[29][m] += test_property((generalisation(generalisation(vector_1, vector_2, h), vector_1b, h) == generalisation(vector_1, generalisation(vector_2, vector_1b, h), h)).all())

        # Test 7
        results.iloc[30][m] += test_property((specification(generalisation(vector_1, vector_2, h), vector_1b, h) == specification(vector_1, generalisation(vector_2, vector_1b, h), h)).all())

        # Test 8
        results.iloc[30][m] += test_property((generalisation(specification(vector_1, vector_2, h), vector_1b, h) == generalisation(vector_1, specification(vector_2, vector_1b, h), h)).all())

        # Test 9
        results.iloc[31][m] += test_property(similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h), generalisation(vector_1, vector_2, h), j) > similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h) , generalisation(generalisation(vector_1, vector_2, h), vector_3, h), j))

        # Test 10
        results.iloc[31][m] += test_property(similarity(specification(specification(vector_1, vector_2, h), vector_2, h), specification(vector_1, vector_2, h), j) > similarity(specification(specification(vector_1, vector_2, h), vector_2, h) , specification(specification(vector_1, vector_2, h), vector_3, h), j))

        # Test 11
        results.iloc[32][m] += test_property(similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h), vector_1, j) > similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h) , vector_2, j))

        # Test 12
        results.iloc[32][m] += test_property(similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h), vector_1, j) > similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h) , vector_2, j))

        # Test 13
        results.iloc[33][m] += test_property(similarity(specification(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))

        # Test 14
        results.iloc[33][m] += test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))

        # Test 15
        results.iloc[34][m] += test_property(similarity(vector_1, vector_1, j) > similarity(vector_2, vector_2, j))

        # Test 16
        results.iloc[35][m] += test_property(similarity(vector_1, specification(vector_1, vector_2, h), j) < similarity(specification(vector_1, vector_2, h), vector_1, j))

        # Test 17
        results.iloc[35][m] += test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) < similarity(vector_1, generalisation(vector_1, vector_2, h), j))

        if q % 345 == 0:
          print('Progress: ' + str(round(q *100 /(len(summaries) * 165),2)) + '%')
print('Progress: 100%!')
# Out:
# Progress: 0%
# /tmp/ipykernel_98198/148325860.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text_1 = summaries.iloc[i][0] # r
# /tmp/ipykernel_98198/148325860.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text_2 = summaries.iloc[i][1] # r_1
# /tmp/ipykernel_98198/148325860.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text_3 = summaries.iloc[i][2] # r_2
# /tmp/ipykernel_98198/148325860.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[24][m] += test_property(information_quantity(vector_1) != information_quantity(vector_2))
# /tmp/ipykernel_98198/148325860.py:23: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[24][m] += test_property(information_quantity(vector_1) != information_quantity(vector_2))
# /tmp/ipykernel_98198/148325860.py:26: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[25][m] += test_property(information_quantity(projection(" ", comp_fun = k)) == 0)
# /tmp/ipykernel_98198/148325860.py:26: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[25][m] += test_property(information_quantity(projection(" ", comp_fun = k)) == 0)
# /tmp/ipykernel_98198/148325860.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[26][m] += test_property(information_quantity(vector_2) < information_quantity(vector_1))
# /tmp/ipykernel_98198/148325860.py:29: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[26][m] += test_property(information_quantity(vector_2) < information_quantity(vector_1))
# /tmp/ipykernel_98198/148325860.py:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[27][m] += test_property((information_quantity(vector_1) < information_quantity(specification(vector_1, vector_2, h)) and information_quantity(vector_2) < information_quantity(specification(vector_1, vector_2, h))))
# /tmp/ipykernel_98198/148325860.py:32: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[27][m] += test_property((information_quantity(vector_1) < information_quantity(specification(vector_1, vector_2, h)) and information_quantity(vector_2) < information_quantity(specification(vector_1, vector_2, h))))
# /tmp/ipykernel_98198/148325860.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[27][m] += test_property((information_quantity(vector_1) > information_quantity(generalisation(vector_1, vector_2, h)) and information_quantity(vector_2) > information_quantity(generalisation(vector_1, vector_2, h))))
# /tmp/ipykernel_98198/148325860.py:35: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[27][m] += test_property((information_quantity(vector_1) > information_quantity(generalisation(vector_1, vector_2, h)) and information_quantity(vector_2) > information_quantity(generalisation(vector_1, vector_2, h))))
# /tmp/ipykernel_98198/148325860.py:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[28][m] += test_property((specification(vector_1, vector_2, h) == specification(vector_2, vector_1, h)).all())
# /tmp/ipykernel_98198/148325860.py:38: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[28][m] += test_property((specification(vector_1, vector_2, h) == specification(vector_2, vector_1, h)).all())
# /tmp/ipykernel_98198/148325860.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[28][m] += test_property((generalisation(vector_1, vector_2, h) == generalisation(vector_2, vector_1, h)).all())
# /tmp/ipykernel_98198/148325860.py:41: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[28][m] += test_property((generalisation(vector_1, vector_2, h) == generalisation(vector_2, vector_1, h)).all())
# /tmp/ipykernel_98198/148325860.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[29][m] += test_property((specification(specification(vector_1, vector_2, h), vector_1b, h) == specification(vector_1, specification(vector_2, vector_1b, h), h)).all())
# /tmp/ipykernel_98198/148325860.py:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[29][m] += test_property((specification(specification(vector_1, vector_2, h), vector_1b, h) == specification(vector_1, specification(vector_2, vector_1b, h), h)).all())
# /tmp/ipykernel_98198/148325860.py:47: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[29][m] += test_property((generalisation(generalisation(vector_1, vector_2, h), vector_1b, h) == generalisation(vector_1, generalisation(vector_2, vector_1b, h), h)).all())
# /tmp/ipykernel_98198/148325860.py:47: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[29][m] += test_property((generalisation(generalisation(vector_1, vector_2, h), vector_1b, h) == generalisation(vector_1, generalisation(vector_2, vector_1b, h), h)).all())
# /tmp/ipykernel_98198/148325860.py:50: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[30][m] += test_property((specification(generalisation(vector_1, vector_2, h), vector_1b, h) == specification(vector_1, generalisation(vector_2, vector_1b, h), h)).all())
# /tmp/ipykernel_98198/148325860.py:50: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[30][m] += test_property((specification(generalisation(vector_1, vector_2, h), vector_1b, h) == specification(vector_1, generalisation(vector_2, vector_1b, h), h)).all())
# /tmp/ipykernel_98198/148325860.py:53: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[30][m] += test_property((generalisation(specification(vector_1, vector_2, h), vector_1b, h) == generalisation(vector_1, specification(vector_2, vector_1b, h), h)).all())
# /tmp/ipykernel_98198/148325860.py:53: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[30][m] += test_property((generalisation(specification(vector_1, vector_2, h), vector_1b, h) == generalisation(vector_1, specification(vector_2, vector_1b, h), h)).all())
# /tmp/ipykernel_98198/148325860.py:56: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[31][m] += test_property(similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h), generalisation(vector_1, vector_2, h), j) > similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h) , generalisation(generalisation(vector_1, vector_2, h), vector_3, h), j))
# /tmp/ipykernel_98198/148325860.py:56: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[31][m] += test_property(similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h), generalisation(vector_1, vector_2, h), j) > similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h) , generalisation(generalisation(vector_1, vector_2, h), vector_3, h), j))
# /tmp/ipykernel_98198/148325860.py:59: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[31][m] += test_property(similarity(specification(specification(vector_1, vector_2, h), vector_2, h), specification(vector_1, vector_2, h), j) > similarity(specification(specification(vector_1, vector_2, h), vector_2, h) , specification(specification(vector_1, vector_2, h), vector_3, h), j))
# /tmp/ipykernel_98198/148325860.py:59: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[31][m] += test_property(similarity(specification(specification(vector_1, vector_2, h), vector_2, h), specification(vector_1, vector_2, h), j) > similarity(specification(specification(vector_1, vector_2, h), vector_2, h) , specification(specification(vector_1, vector_2, h), vector_3, h), j))
# /tmp/ipykernel_98198/148325860.py:62: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[32][m] += test_property(similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h), vector_1, j) > similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h) , vector_2, j))
# /tmp/ipykernel_98198/148325860.py:62: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[32][m] += test_property(similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h), vector_1, j) > similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h) , vector_2, j))
# /tmp/ipykernel_98198/148325860.py:65: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[32][m] += test_property(similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h), vector_1, j) > similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h) , vector_2, j))
# /tmp/ipykernel_98198/148325860.py:65: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[32][m] += test_property(similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h), vector_1, j) > similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h) , vector_2, j))
# /tmp/ipykernel_98198/148325860.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[33][m] += test_property(similarity(specification(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))
# /tmp/ipykernel_98198/148325860.py:68: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[33][m] += test_property(similarity(specification(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))
# /tmp/ipykernel_98198/148325860.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[33][m] += test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))
# /tmp/ipykernel_98198/148325860.py:71: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[33][m] += test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))
# /tmp/ipykernel_98198/148325860.py:74: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[34][m] += test_property(similarity(vector_1, vector_1, j) > similarity(vector_2, vector_2, j))
# /tmp/ipykernel_98198/148325860.py:74: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[34][m] += test_property(similarity(vector_1, vector_1, j) > similarity(vector_2, vector_2, j))
# /tmp/ipykernel_98198/148325860.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[35][m] += test_property(similarity(vector_1, specification(vector_1, vector_2, h), j) < similarity(specification(vector_1, vector_2, h), vector_1, j))
# /tmp/ipykernel_98198/148325860.py:77: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[35][m] += test_property(similarity(vector_1, specification(vector_1, vector_2, h), j) < similarity(specification(vector_1, vector_2, h), vector_1, j))
# /tmp/ipykernel_98198/148325860.py:80: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[35][m] += test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) < similarity(vector_1, generalisation(vector_1, vector_2, h), j))
# /tmp/ipykernel_98198/148325860.py:80: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[35][m] += test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) < similarity(vector_1, generalisation(vector_1, vector_2, h), j))
# Progress: 4.18%
# Progress: 8.36%
# Progress: 12.55%
# Progress: 16.73%
# Progress: 20.91%
# Progress: 25.09%
# Progress: 29.27%
# Progress: 33.45%
# Progress: 37.64%
# Progress: 41.82%
# Progress: 46.0%
# Progress: 50.18%
# Progress: 54.36%
# Progress: 58.55%
# Progress: 62.73%
# Progress: 66.91%
# Progress: 71.09%
# Progress: 75.27%
# Progress: 79.45%
# Progress: 83.64%
# Progress: 87.82%
# Progress: 92.0%
# Progress: 96.18%
# Progress: 100%!

# %% [markdown]
# # Results comparison

# %%
test_number = [1, 1, 1, 2, 2, 2, 2, 2, 2, 2, 1, 2]
sequence_normalizer = [x * len(sequences) for x in test_number]
ancestors_normalizer = [x * len(ancestors) for x in test_number]
summaries_normalizer = [x * len(summaries) for x in test_number]

normalizer = sequence_normalizer + ancestors_normalizer + summaries_normalizer

normalized_results = results.div(normalizer, axis=0).round(2)

# %%
normalized_results.to_csv('./results/normalized_results.csv')

# %%
groups = [normalized_results.iloc[i:i+12] for i in range(0, len(normalized_results), 12)]

sums = [group.sum() for group in groups]

sums_df = pd.concat(sums, axis=1, keys=[f'Group_{i+1}' for i in range(len(groups))])

total_sum = normalized_results.sum()
sums_df['Total_Sum'] = total_sum

# %%
analysis_df = sums_df['Total_Sum']

# %% [markdown]
# # Embedding analysis

# %%
# Dividir la columna en segmentos de 33 elementos cada uno
segmentos = [analysis_df.iloc[i:i+33].reset_index(drop=True) for i in range(0, len(analysis_df), 33)]

# Crear un nuevo DataFrame con las columnas deseadas
nuevo_df = pd.concat(segmentos, axis=1, ignore_index=True)

nuevo_df.columns = ['Sum of Vectors', 'Average', 'F_joint', 'F_ind', 'F_inf']

# Nombrar las filas del nuevo DataFrame
nuevo_df.index = ['Algebraic - Cosine',
'Algebraic - Euclidean',
'Algebraic - Dot',
'Algebraic - ICM_100_100_150',
'Algebraic - ICM_150_050_150',
'Algebraic - ICM_175_075_15',
'Algebraic - ICM_150_050_100',
'Algebraic - ICM_150_050_200',
'Algebraic - ICM_050_150_150',
'Algebraic - ICM_050_150_050',
'Algebraic - ICM_150_100_150',
'Information - Cosine',
'Information - Euclidean',
'Information - Dot',
'Information - ICM_100_100_150',
'Information - ICM_150_050_150',
'Information - ICM_175_075_15',
'Information - ICM_150_050_100',
'Information - ICM_150_050_200',
'Information - ICM_050_150_150',
'Information - ICM_050_150_050',
'Information - ICM_150_100_150',
'Fuzzy - Cosine',
'Fuzzy - Euclidean',
'Fuzzy - Dot',
'Fuzzy - ICM_100_100_150',
'Fuzzy - ICM_150_050_150',
'Fuzzy - ICM_175_075_15',
'Fuzzy - ICM_150_050_100',
'Fuzzy - ICM_150_050_200',
'Fuzzy - ICM_050_150_150',
'Fuzzy - ICM_050_150_050',
'Fuzzy - ICM_150_100_150'  ]

latex_table = nuevo_df.to_latex()
print(latex_table)
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
#  & Sum of Vectors & Average & F_joint & F_ind & F_inf \\
# \midrule
# Algebraic - Cosine & 19.820000 & 20.920000 & 21.120000 & 20.720000 & 20.740000 \\
# Algebraic - Euclidean & 16.300000 & 15.470000 & 16.390000 & 16.930000 & 16.790000 \\
# Algebraic - Dot & 21.030000 & 18.960000 & 20.490000 & 21.350000 & 21.350000 \\
# Algebraic - ICM_100_100_150 & 22.330000 & 21.160000 & 22.450000 & 22.760000 & 22.960000 \\
# Algebraic - ICM_150_050_150 & 23.220000 & 22.350000 & 23.780000 & 23.910000 & 24.140000 \\
# Algebraic - ICM_175_075_15 & 21.600000 & 20.710000 & 22.210000 & 22.230000 & 22.600000 \\
# Algebraic - ICM_150_050_100 & 21.450000 & 20.490000 & 21.970000 & 22.050000 & 22.460000 \\
# Algebraic - ICM_150_050_200 & 22.030000 & 21.220000 & 22.500000 & 22.550000 & 22.700000 \\
# Algebraic - ICM_050_150_150 & 21.600000 & 18.490000 & 20.240000 & 21.260000 & 21.040000 \\
# Algebraic - ICM_050_150_050 & 20.800000 & 18.160000 & 19.790000 & 20.800000 & 20.740000 \\
# Algebraic - ICM_150_100_150 & 21.560000 & 20.420000 & 21.810000 & 22.160000 & 22.320000 \\
# Information - Cosine & 21.670000 & 22.610000 & 22.590000 & 22.080000 & 22.030000 \\
# Information - Euclidean & 14.630000 & 12.780000 & 13.890000 & 14.620000 & 14.350000 \\
# Information - Dot & 22.990000 & 21.100000 & 22.770000 & 23.260000 & 23.270000 \\
# Information - ICM_100_100_150 & 25.020000 & 23.000000 & 24.290000 & 25.110000 & 24.920000 \\
# Information - ICM_150_050_150 & 23.820000 & 22.570000 & 24.050000 & 24.410000 & 24.510000 \\
# Information - ICM_175_075_15 & 23.550000 & 21.740000 & 23.340000 & 23.830000 & 23.910000 \\
# Information - ICM_150_050_100 & 23.210000 & 20.860000 & 22.540000 & 23.260000 & 23.270000 \\
# Information - ICM_150_050_200 & 22.370000 & 21.740000 & 22.780000 & 22.760000 & 23.060000 \\
# Information - ICM_050_150_150 & 24.700000 & 22.680000 & 24.020000 & 24.800000 & 24.630000 \\
# Information - ICM_050_150_050 & 21.560000 & 19.620000 & 21.310000 & 21.830000 & 21.840000 \\
# Information - ICM_150_100_150 & 23.660000 & 22.090000 & 23.460000 & 23.860000 & 23.960000 \\
# Fuzzy - Cosine & 24.260000 & 24.460000 & 24.770000 & 24.500000 & 24.350000 \\
# Fuzzy - Euclidean & 17.560000 & 15.770000 & 16.800000 & 17.550000 & 17.270000 \\
# Fuzzy - Dot & 25.890000 & 23.470000 & 24.800000 & 25.720000 & 25.500000 \\
# Fuzzy - ICM_100_100_150 & 28.060000 & 25.690000 & 27.260000 & 28.130000 & 27.850000 \\
# Fuzzy - ICM_150_050_150 & 26.170000 & 24.450000 & 25.830000 & 26.400000 & 26.320000 \\
# Fuzzy - ICM_175_075_15 & 25.720000 & 24.020000 & 25.310000 & 25.920000 & 25.960000 \\
# Fuzzy - ICM_150_050_100 & 25.370000 & 23.330000 & 24.820000 & 25.470000 & 25.500000 \\
# Fuzzy - ICM_150_050_200 & 24.890000 & 23.900000 & 24.980000 & 25.180000 & 25.290000 \\
# Fuzzy - ICM_050_150_150 & 27.630000 & 25.090000 & 26.610000 & 27.540000 & 27.300000 \\
# Fuzzy - ICM_050_150_050 & 25.420000 & 23.250000 & 24.620000 & 25.410000 & 25.190000 \\
# Fuzzy - ICM_150_100_150 & 26.380000 & 24.250000 & 25.730000 & 26.400000 & 26.310000 \\
# \bottomrule
# \end{tabular}

# %%
# Configurar el estilo y colores contrastantes
sns.set_palette("tab10")  # Utilizar una paleta de colores de Seaborn
#plt.style.use('seaborn')

# Crear un gráfico de dispersión
plt.figure(figsize=(10, 6))
for columna in nuevo_df.columns:
    plt.scatter(nuevo_df.index, nuevo_df[columna], label=columna)

# Configurar etiquetas y título

plt.ylabel('Score')
plt.title('Embedding functions analysis')
plt.xticks(rotation='vertical')  # Rotar las etiquetas del eje X en vertical
plt.legend()

# Mostrar el gráfico
plt.tight_layout()  # Ajustar el diseño
plt.savefig('./results/img/embedding_analysis.png', dpi=300)


plt.show()

# %% [markdown]
# # Specification and generalization fucntions analysis

# %%
# Definir los índices de los grupos
indices_grupo1 = list(range(0, 11)) + list(range(33, 44)) + list(range(66, 77))+ list(range(99, 110))+ list(range(132, 143))
indices_grupo2 = list(range(11, 22)) + list(range(44, 55)) + list(range(77, 88))+ list(range(110, 121))+ list(range(143, 154))
indices_grupo3 = list(range(22, 33)) + list(range(55, 66)) + list(range(88, 99))+ list(range(121, 132))+ list(range(154, 165))

# Crear los grupos
grupo1 = list(analysis_df.iloc[indices_grupo1])
grupo2 = list(analysis_df.iloc[indices_grupo2])
grupo3 = list(analysis_df.iloc[indices_grupo3])

# Crear el DataFrame
nombres_filas = [
'Sum of Vectors - Cosine',
'Sum of Vectors - Euclidean',
'Sum of Vectors - Dot',
'Sum of Vectors - ICM_100_100_150',
'Sum of Vectors - ICM_150_050_150',
'Sum of Vectors - ICM_175_075_15',
'Sum of Vectors - ICM_150_050_100',
'Sum of Vectors - ICM_150_050_200',
'Sum of Vectors - ICM_050_150_150',
'Sum of Vectors - ICM_050_150_050',
'Sum of Vectors - ICM_150_100_150',
'Average - Cosine',
'Average - Euclidean',
'Average - Dot',
'Average - ICM_100_100_150',
'Average - ICM_150_050_150',
'Average - ICM_175_075_15',
'Average - ICM_150_050_100',
'Average - ICM_150_050_200',
'Average - ICM_050_150_150',
'Average - ICM_050_150_050',
'Average - ICM_150_100_150',
'F_joint - Cosine',
'F_joint - Euclidean',
'F_joint - Dot',
'F_joint - ICM_100_100_150',
'F_joint - ICM_150_050_150',
'F_joint - ICM_175_075_15',
'F_joint - ICM_150_050_100',
'F_joint - ICM_150_050_200',
'F_joint - ICM_050_150_150',
'F_joint - ICM_050_150_050',
'F_joint - ICM_150_100_150',
'F_ind - Cosine',
'F_ind - Euclidean',
'F_ind - Dot',
'F_ind - ICM_100_100_150',
'F_ind - ICM_150_050_150',
'F_ind - ICM_175_075_15',
'F_ind - ICM_150_050_100',
'F_ind - ICM_150_050_200',
'F_ind - ICM_050_150_150',
'F_ind - ICM_050_150_050',
'F_ind - ICM_150_100_150',
'F_inf - Cosine',
'F_inf - Euclidean',
'F_inf - Dot',
'F_inf - ICM_100_100_150',
'F_inf - ICM_150_050_150',
'F_inf - ICM_175_075_15',
'F_inf - ICM_150_050_100',
'F_inf - ICM_150_050_200',
'F_inf - ICM_050_150_150',
'F_inf - ICM_050_150_050',
'F_inf - ICM_150_100_150'
    ]

data = {'Algebraic': grupo1, 'Information': grupo2, 'Fuzzy': grupo3}
nuevo_df = pd.DataFrame(data, index=nombres_filas)

latex_table = nuevo_df.to_latex()
print(latex_table)
# Out:
# \begin{tabular}{lrrr}
# \toprule
#  & Algebraic & Information & Fuzzy \\
# \midrule
# Sum of Vectors - Cosine & 19.820000 & 21.670000 & 24.260000 \\
# Sum of Vectors - Euclidean & 16.300000 & 14.630000 & 17.560000 \\
# Sum of Vectors - Dot & 21.030000 & 22.990000 & 25.890000 \\
# Sum of Vectors - ICM_100_100_150 & 22.330000 & 25.020000 & 28.060000 \\
# Sum of Vectors - ICM_150_050_150 & 23.220000 & 23.820000 & 26.170000 \\
# Sum of Vectors - ICM_175_075_15 & 21.600000 & 23.550000 & 25.720000 \\
# Sum of Vectors - ICM_150_050_100 & 21.450000 & 23.210000 & 25.370000 \\
# Sum of Vectors - ICM_150_050_200 & 22.030000 & 22.370000 & 24.890000 \\
# Sum of Vectors - ICM_050_150_150 & 21.600000 & 24.700000 & 27.630000 \\
# Sum of Vectors - ICM_050_150_050 & 20.800000 & 21.560000 & 25.420000 \\
# Sum of Vectors - ICM_150_100_150 & 21.560000 & 23.660000 & 26.380000 \\
# Average - Cosine & 20.920000 & 22.610000 & 24.460000 \\
# Average - Euclidean & 15.470000 & 12.780000 & 15.770000 \\
# Average - Dot & 18.960000 & 21.100000 & 23.470000 \\
# Average - ICM_100_100_150 & 21.160000 & 23.000000 & 25.690000 \\
# Average - ICM_150_050_150 & 22.350000 & 22.570000 & 24.450000 \\
# Average - ICM_175_075_15 & 20.710000 & 21.740000 & 24.020000 \\
# Average - ICM_150_050_100 & 20.490000 & 20.860000 & 23.330000 \\
# Average - ICM_150_050_200 & 21.220000 & 21.740000 & 23.900000 \\
# Average - ICM_050_150_150 & 18.490000 & 22.680000 & 25.090000 \\
# Average - ICM_050_150_050 & 18.160000 & 19.620000 & 23.250000 \\
# Average - ICM_150_100_150 & 20.420000 & 22.090000 & 24.250000 \\
# F_joint - Cosine & 21.120000 & 22.590000 & 24.770000 \\
# F_joint - Euclidean & 16.390000 & 13.890000 & 16.800000 \\
# F_joint - Dot & 20.490000 & 22.770000 & 24.800000 \\
# F_joint - ICM_100_100_150 & 22.450000 & 24.290000 & 27.260000 \\
# F_joint - ICM_150_050_150 & 23.780000 & 24.050000 & 25.830000 \\
# F_joint - ICM_175_075_15 & 22.210000 & 23.340000 & 25.310000 \\
# F_joint - ICM_150_050_100 & 21.970000 & 22.540000 & 24.820000 \\
# F_joint - ICM_150_050_200 & 22.500000 & 22.780000 & 24.980000 \\
# F_joint - ICM_050_150_150 & 20.240000 & 24.020000 & 26.610000 \\
# F_joint - ICM_050_150_050 & 19.790000 & 21.310000 & 24.620000 \\
# F_joint - ICM_150_100_150 & 21.810000 & 23.460000 & 25.730000 \\
# F_ind - Cosine & 20.720000 & 22.080000 & 24.500000 \\
# F_ind - Euclidean & 16.930000 & 14.620000 & 17.550000 \\
# F_ind - Dot & 21.350000 & 23.260000 & 25.720000 \\
# F_ind - ICM_100_100_150 & 22.760000 & 25.110000 & 28.130000 \\
# F_ind - ICM_150_050_150 & 23.910000 & 24.410000 & 26.400000 \\
# F_ind - ICM_175_075_15 & 22.230000 & 23.830000 & 25.920000 \\
# F_ind - ICM_150_050_100 & 22.050000 & 23.260000 & 25.470000 \\
# F_ind - ICM_150_050_200 & 22.550000 & 22.760000 & 25.180000 \\
# F_ind - ICM_050_150_150 & 21.260000 & 24.800000 & 27.540000 \\
# F_ind - ICM_050_150_050 & 20.800000 & 21.830000 & 25.410000 \\
# F_ind - ICM_150_100_150 & 22.160000 & 23.860000 & 26.400000 \\
# F_inf - Cosine & 20.740000 & 22.030000 & 24.350000 \\
# F_inf - Euclidean & 16.790000 & 14.350000 & 17.270000 \\
# F_inf - Dot & 21.350000 & 23.270000 & 25.500000 \\
# F_inf - ICM_100_100_150 & 22.960000 & 24.920000 & 27.850000 \\
# F_inf - ICM_150_050_150 & 24.140000 & 24.510000 & 26.320000 \\
# F_inf - ICM_175_075_15 & 22.600000 & 23.910000 & 25.960000 \\
# F_inf - ICM_150_050_100 & 22.460000 & 23.270000 & 25.500000 \\
# F_inf - ICM_150_050_200 & 22.700000 & 23.060000 & 25.290000 \\
# F_inf - ICM_050_150_150 & 21.040000 & 24.630000 & 27.300000 \\
# F_inf - ICM_050_150_050 & 20.740000 & 21.840000 & 25.190000 \\
# F_inf - ICM_150_100_150 & 22.320000 & 23.960000 & 26.310000 \\
# \bottomrule
# \end{tabular}

# %%
# Configurar el estilo y colores contrastantes
sns.set_palette("tab10")  # Utilizar una paleta de colores de Seaborn
#plt.style.use('seaborn-pastel')

# Crear un gráfico de dispersión
plt.figure(figsize=(10, 6))
for columna in nuevo_df.columns:
    plt.scatter(nuevo_df.index, nuevo_df[columna], label=columna)

# Configurar etiquetas y título

plt.ylabel('Score')
plt.title('Specification and generalization functions analysis')
plt.xticks(rotation='vertical')  # Rotar las etiquetas del eje X en vertical
plt.legend()

# Mostrar el gráfico
plt.tight_layout()  # Ajustar el diseño
plt.savefig('./results/img/generalisation_analysis.png', dpi=300)


plt.show()

# %% [markdown]
# # Similarity function analysis

# %%
# Definir los índices de los grupos
indices_grupo1 = list(range(0, 165, 11))
indices_grupo2 = [elem + 1 for elem in indices_grupo1]
indices_grupo3 = [elem + 2 for elem in indices_grupo1]
indices_grupo4 = [elem + 3 for elem in indices_grupo1]
indices_grupo5 = [elem + 4 for elem in indices_grupo1]
indices_grupo6 = [elem + 5 for elem in indices_grupo1]
indices_grupo7 = [elem + 6 for elem in indices_grupo1]
indices_grupo8 = [elem + 7 for elem in indices_grupo1]
indices_grupo9 = [elem + 8 for elem in indices_grupo1]
indices_grupo10 = [elem + 9 for elem in indices_grupo1]
indices_grupo11 = [elem + 10 for elem in indices_grupo1]

# Crear los grupos
grupo1 = list(analysis_df.iloc[indices_grupo1])
grupo2 = list(analysis_df.iloc[indices_grupo2])
grupo3 = list(analysis_df.iloc[indices_grupo3])
grupo4 = list(analysis_df.iloc[indices_grupo4])
grupo5 = list(analysis_df.iloc[indices_grupo5])
grupo6 = list(analysis_df.iloc[indices_grupo6])
grupo7 = list(analysis_df.iloc[indices_grupo7])
grupo8 = list(analysis_df.iloc[indices_grupo8])
grupo9 = list(analysis_df.iloc[indices_grupo9])
grupo10 = list(analysis_df.iloc[indices_grupo10])
grupo11 = list(analysis_df.iloc[indices_grupo11])

# Crear el DataFrame
nombres_filas = [
'Sum of Vectors - Algebraic',
'Sum of Vectors - Information',
'Sum of Vectors - Fuzzy',
'Average - Algebraic',
'Average - Information',
'Average - Fuzzy',
'F_joint - Algebraic',
'F_joint - Information',
'F_joint - Fuzzy',
'F_ind - Algebraic',
'F_ind - Information',
'F_ind - Fuzzy',
'F_inf - Algebraic',
'F_inf - Information',
'F_inf - Fuzzy'
    ]

data = {'Cosine': grupo1, 'Euclidean': grupo2, 'Dot': grupo3, 'ICM_100_100_150': grupo4, 'ICM_150_050_150': grupo5, 'ICM_175_075_15': grupo6, 'ICM_150_050_100': grupo7, 'ICM_150_050_200': grupo8, 'ICM_050_150_150': grupo9, 'ICM_050_150_050': grupo10, 'ICM_150_100_150': grupo11}
nuevo_df = pd.DataFrame(data, index=nombres_filas)

latex_table = nuevo_df.to_latex()
print(latex_table)
# Out:
# \begin{tabular}{lrrrrrrrrrrr}
# \toprule
#  & Cosine & Euclidean & Dot & ICM_100_100_150 & ICM_150_050_150 & ICM_175_075_15 & ICM_150_050_100 & ICM_150_050_200 & ICM_050_150_150 & ICM_050_150_050 & ICM_150_100_150 \\
# \midrule
# Sum of Vectors - Algebraic & 19.820000 & 16.300000 & 21.030000 & 22.330000 & 23.220000 & 21.600000 & 21.450000 & 22.030000 & 21.600000 & 20.800000 & 21.560000 \\
# Sum of Vectors - Information & 21.670000 & 14.630000 & 22.990000 & 25.020000 & 23.820000 & 23.550000 & 23.210000 & 22.370000 & 24.700000 & 21.560000 & 23.660000 \\
# Sum of Vectors - Fuzzy & 24.260000 & 17.560000 & 25.890000 & 28.060000 & 26.170000 & 25.720000 & 25.370000 & 24.890000 & 27.630000 & 25.420000 & 26.380000 \\
# Average - Algebraic & 20.920000 & 15.470000 & 18.960000 & 21.160000 & 22.350000 & 20.710000 & 20.490000 & 21.220000 & 18.490000 & 18.160000 & 20.420000 \\
# Average - Information & 22.610000 & 12.780000 & 21.100000 & 23.000000 & 22.570000 & 21.740000 & 20.860000 & 21.740000 & 22.680000 & 19.620000 & 22.090000 \\
# Average - Fuzzy & 24.460000 & 15.770000 & 23.470000 & 25.690000 & 24.450000 & 24.020000 & 23.330000 & 23.900000 & 25.090000 & 23.250000 & 24.250000 \\
# F_joint - Algebraic & 21.120000 & 16.390000 & 20.490000 & 22.450000 & 23.780000 & 22.210000 & 21.970000 & 22.500000 & 20.240000 & 19.790000 & 21.810000 \\
# F_joint - Information & 22.590000 & 13.890000 & 22.770000 & 24.290000 & 24.050000 & 23.340000 & 22.540000 & 22.780000 & 24.020000 & 21.310000 & 23.460000 \\
# F_joint - Fuzzy & 24.770000 & 16.800000 & 24.800000 & 27.260000 & 25.830000 & 25.310000 & 24.820000 & 24.980000 & 26.610000 & 24.620000 & 25.730000 \\
# F_ind - Algebraic & 20.720000 & 16.930000 & 21.350000 & 22.760000 & 23.910000 & 22.230000 & 22.050000 & 22.550000 & 21.260000 & 20.800000 & 22.160000 \\
# F_ind - Information & 22.080000 & 14.620000 & 23.260000 & 25.110000 & 24.410000 & 23.830000 & 23.260000 & 22.760000 & 24.800000 & 21.830000 & 23.860000 \\
# F_ind - Fuzzy & 24.500000 & 17.550000 & 25.720000 & 28.130000 & 26.400000 & 25.920000 & 25.470000 & 25.180000 & 27.540000 & 25.410000 & 26.400000 \\
# F_inf - Algebraic & 20.740000 & 16.790000 & 21.350000 & 22.960000 & 24.140000 & 22.600000 & 22.460000 & 22.700000 & 21.040000 & 20.740000 & 22.320000 \\
# F_inf - Information & 22.030000 & 14.350000 & 23.270000 & 24.920000 & 24.510000 & 23.910000 & 23.270000 & 23.060000 & 24.630000 & 21.840000 & 23.960000 \\
# F_inf - Fuzzy & 24.350000 & 17.270000 & 25.500000 & 27.850000 & 26.320000 & 25.960000 & 25.500000 & 25.290000 & 27.300000 & 25.190000 & 26.310000 \\
# \bottomrule
# \end{tabular}

# %%
# Configurar el estilo y colores contrastantes
sns.set_palette("tab10")  # Utilizar una paleta de colores de Seaborn
#plt.style.use('seaborn-pastel')

# Crear un gráfico de dispersión
plt.figure(figsize=(10, 6))
for columna in nuevo_df.columns:
    plt.scatter(nuevo_df.index, nuevo_df[columna], label=columna)

# Configurar etiquetas y título

plt.ylabel('Score')
plt.title('Similarity functions analysis')
plt.xticks(rotation='vertical')  # Rotar las etiquetas del eje X en vertical
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Mostrar el gráfico
plt.tight_layout()  # Ajustar el diseño
plt.savefig('./results/img/similarity_analysis.png', dpi=300)


plt.show()

# %% [markdown]
# # Star charts

# %%
print('Progress: 0%')
q = 0
# Define el número de cuadrantes
num_cuadrantes = 12
# Asignar colores a los cuadrantes
colors = ['coral', 'coral', 'coral', 'coral', 'aquamarine', 'aquamarine', 'aquamarine', 'aquamarine', 'aquamarine', 'steelblue', 'steelblue', 'steelblue']

theta=['Constraint 1 - Injectivity', 'Constraint 2 - Zero informativeness', 'Constraint 3 - Infinite informativeness', 'Constraint 4 - Upper and lower bounds',
          'Constraint 5 - Commutativity', 'Constraint 6 - Associativity', 'Constraint 7 - Distributiveness', 'Constraint 8 - Idempotency',
          'Constraint 9 - Identity', 'Constraint 10 - Similarity monotonicity', 'Constraint 11 - Self-similarity', 'Constraint 12 - Asymmetricity']


for i in range(165):
  q += 1
  df = pd.DataFrame(dict(
      r=normalized_results.iloc[:12, i],
      theta=['Constraint 1 - Injectivity', 'Constraint 2 - Zero informativeness', 'Constraint 3 - Infinite informativeness', 'Constraint 4 - Upper and lower bounds',
          'Constraint 5 - Commutativity', 'Constraint 6 - Associativity', 'Constraint 7 - Distributiveness', 'Constraint 8 - Idempotency',
          'Constraint 9 - Identity', 'Constraint 10 - Similarity monotonicity', 'Constraint 11 - Self-similarity', 'Constraint 12 - Asymmetricity']))
   # Crear el gráfico polar
  fig = go.Figure()

  for pp in range(num_cuadrantes):
      r1_data = df.iloc[pp]['r']
      theta_data = df.iloc[pp]['theta']
      # Agregar la serie 1 al gráfico
      fig.add_trace(go.Barpolar(
          r=[r1_data, 0],  # Los datos de la serie 1 y un valor cero para el centro del gráfico
          theta=[theta_data, theta_data],  # Las coordenadas angulares
          name='Serie 1',
          marker_color=colors[pp % len(colors)],  # Selecciona un color para el cuadrante
          showlegend=False  # No mostrar la leyenda para cada cuadrante
      ))

  # Personaliza el diseño del gráfico polar
  fig.update_layout(
      polar=dict(
          radialaxis=dict(range=[0, 1]),
          angularaxis=dict(direction="clockwise", showline=False)
      ),
      title=normalized_results.columns[i] + ' - Aggregated results',
      title_x=0.5,
      title_y=0.99
  )
  fig.write_image('./results/img/' + normalized_results.columns[i] + ' - Sequences results.png', width=1500, height=1080)


  df = pd.DataFrame(dict(
      r=normalized_results.iloc[12:24, i],
      theta=['Constraint 1 - Injectivity', 'Constraint 2 - Zero informativeness', 'Constraint 3 - Infinite informativeness', 'Constraint 4 - Upper and lower bounds',
          'Constraint 5 - Commutativity', 'Constraint 6 - Associativity', 'Constraint 7 - Distributiveness', 'Constraint 8 - Idempotency',
          'Constraint 9 - Identity', 'Constraint 10 - Similarity monotonicity', 'Constraint 11 - Self-similarity', 'Constraint 12 - Asymmetricity']))
   # Crear el gráfico polar
  fig = go.Figure()

  for pp in range(num_cuadrantes):
      r1_data = df.iloc[pp]['r']
      theta_data = df.iloc[pp]['theta']
      # Agregar la serie 1 al gráfico
      fig.add_trace(go.Barpolar(
          r=[r1_data, 0],  # Los datos de la serie 1 y un valor cero para el centro del gráfico
          theta=[theta_data, theta_data],  # Las coordenadas angulares
          name='Serie 1',
          marker_color=colors[pp % len(colors)],  # Selecciona un color para el cuadrante
          showlegend=False  # No mostrar la leyenda para cada cuadrante
      ))

  # Personaliza el diseño del gráfico polar
  fig.update_layout(
      polar=dict(
          radialaxis=dict(range=[0, 1]),
          angularaxis=dict(direction="clockwise", showline=False)
      ),
      title=normalized_results.columns[i] + ' - Aggregated results',
      title_x=0.5,
      title_y=0.99
  )
  fig.write_image('./results/img/' + normalized_results.columns[i] + ' - Ancestors results.png', width=1500, height=1080)


  df = pd.DataFrame(dict(
      r=normalized_results.iloc[24:36, i],
      theta=['Constraint 1 - Injectivity', 'Constraint 2 - Zero informativeness', 'Constraint 3 - Infinite informativeness', 'Constraint 4 - Upper and lower bounds',
          'Constraint 5 - Commutativity', 'Constraint 6 - Associativity', 'Constraint 7 - Distributiveness', 'Constraint 8 - Idempotency',
          'Constraint 9 - Identity', 'Constraint 10 - Similarity monotonicity', 'Constraint 11 - Self-similarity', 'Constraint 12 - Asymmetricity']))
   # Crear el gráfico polar
  fig = go.Figure()

  for pp in range(num_cuadrantes):
      r1_data = df.iloc[pp]['r']
      theta_data = df.iloc[pp]['theta']
      # Agregar la serie 1 al gráfico
      fig.add_trace(go.Barpolar(
          r=[r1_data, 0],  # Los datos de la serie 1 y un valor cero para el centro del gráfico
          theta=[theta_data, theta_data],  # Las coordenadas angulares
          name='Serie 1',
          marker_color=colors[pp % len(colors)],  # Selecciona un color para el cuadrante
          showlegend=False  # No mostrar la leyenda para cada cuadrante
      ))

  # Personaliza el diseño del gráfico polar
  fig.update_layout(
      polar=dict(
          radialaxis=dict(range=[0, 1]),
          angularaxis=dict(direction="clockwise", showline=False)
      ),
      title=normalized_results.columns[i] + ' - Aggregated results',
      title_x=0.5,
      title_y=0.99
  )
  fig.write_image('./results/img/' + normalized_results.columns[i] + ' - Summaries results.png', width=1500, height=1080)


  df = pd.DataFrame(dict(
      r=(normalized_results.iloc[:12, i] + normalized_results.iloc[12:24, i] + normalized_results.iloc[24:36, i]) / 3,
      theta=['Constraint 1 - Injectivity', 'Constraint 2 - Zero informativeness', 'Constraint 3 - Infinite informativeness', 'Constraint 4 - Upper and lower bounds',
          'Constraint 5 - Commutativity', 'Constraint 6 - Associativity', 'Constraint 7 - Distributiveness', 'Constraint 8 - Idempotency',
          'Constraint 9 - Identity', 'Constraint 10 - Similarity monotonicity', 'Constraint 11 - Self-similarity', 'Constraint 12 - Asymmetricity']))

  # Crear el gráfico polar
  fig = go.Figure()

  for pp in range(num_cuadrantes):
      r1_data = df.iloc[pp]['r']
      theta_data = df.iloc[pp]['theta']
      # Agregar la serie 1 al gráfico
      fig.add_trace(go.Barpolar(
          r=[r1_data, 0],  # Los datos de la serie 1 y un valor cero para el centro del gráfico
          theta=[theta_data, theta_data],  # Las coordenadas angulares
          name='Serie 1',
          marker_color=colors[pp % len(colors)],  # Selecciona un color para el cuadrante
          showlegend=False  # No mostrar la leyenda para cada cuadrante
      ))

  # Personaliza el diseño del gráfico polar
  fig.update_layout(
      polar=dict(
          radialaxis=dict(range=[0, 1]),
          angularaxis=dict(direction="clockwise", showline=False)
      ),
      title=normalized_results.columns[i] + ' - Aggregated results',
      title_x=0.5,
      title_y=0.99
  )
  fig.write_image('./results/img/' + normalized_results.columns[i] + ' - Aggregated results.png', width=1500, height=1080)
  #fig.show()

  if q % 8 == 0:
   print('Progress: ' + str(round(q*100/165,2)) + '%')
print('Progress: 100%!')
# Out:
# Progress: 0%
# Progress: 4.85%
# Progress: 9.7%
# Progress: 14.55%
# Progress: 19.39%
# Progress: 24.24%
# Progress: 29.09%
# Progress: 33.94%
# Progress: 38.79%
# Progress: 43.64%
# Progress: 48.48%
# Progress: 53.33%
# Progress: 58.18%
# Progress: 63.03%
# Progress: 67.88%
# Progress: 72.73%
# Progress: 77.58%
# Progress: 82.42%
# Progress: 87.27%
# Progress: 92.12%
# Progress: 96.97%
# Progress: 100%!
