# %% [markdown]
# # Starting point

# %%
import sys
import pandas as pd

sys.path.append('./modules')
from modules import composition, comp_func
from modules.functional import specification, generalisation, information_quantity

from transformers import AutoModel, AutoTokenizer, pipeline

import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import seaborn as sns

# %%
import torch

device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Uncomment if you know your GPU doesn't have enough memory
# device = 'cpu'

#model_name = 'bert-base-cased'
model_name = 'princeton-nlp/sup-simcse-bert-base-uncased'
#model_name = 'meta-llama/Llama-2-7b-hf'
with torch.inference_mode():
    model = AutoModel.from_pretrained(model_name, device_map = device, torch_dtype=torch.bfloat16)
    tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
projection = pipeline('composition', model=model, tokenizer=tokenizer)

# %% [markdown]
# ## Former code

# %%
def test_property(logic_value):
  if logic_value:
    return 1
  else:
    return 0

# %%
import torch
def similarity(vector_1, vector_2, sim_fun):
  if sim_fun == 1:
    scalar_product = torch.dot(vector_1, vector_2)
    squared_module_1 = torch.dot(vector_1, vector_1)
    squared_module_2 = torch.dot(vector_2, vector_2)
    cosine = scalar_product / (squared_module_1 * squared_module_2)
    return cosine

  elif sim_fun == 2:
    return torch.norm(vector_1 - vector_2)

  elif sim_fun == 3:
    return torch.dot(vector_1, vector_2)

  elif sim_fun == 4:
    inf_quant_12 = information_quantity(vector_1) + information_quantity(vector_2) - torch.dot(vector_1, vector_2)
    return information_quantity(vector_1) + information_quantity(vector_2) - 1.5 * inf_quant_12

  elif sim_fun == 5:
    inf_quant_12 = information_quantity(vector_1) + information_quantity(vector_2) - torch.dot(vector_1, vector_2)
    if information_quantity(vector_1) >= information_quantity(vector_2):
      alpha_1 = 1.5
      alpha_2 = 0.5
    else:
      alpha_1 = 0.5
      alpha_2 = 1.5
    beta = 1.5
    return alpha_1 * information_quantity(vector_1) + alpha_2 * information_quantity(vector_2) - beta * inf_quant_12

  elif sim_fun == 6:
    inf_quant_12 = information_quantity(vector_1) + information_quantity(vector_2) - torch.dot(vector_1, vector_2)
    if information_quantity(vector_1) >= information_quantity(vector_2):
      alpha_1 = 1.75
      alpha_2 = 0.75
    else:
      alpha_1 = 0.75
      alpha_2 = 1.75
    beta = 1.5
    return alpha_1 * information_quantity(vector_1) + alpha_2 * information_quantity(vector_2) - beta * inf_quant_12

  elif sim_fun == 7:
    inf_quant_12 = information_quantity(vector_1) + information_quantity(vector_2) - torch.dot(vector_1, vector_2)
    if information_quantity(vector_1) >= information_quantity(vector_2):
      alpha_1 = 1.5
      alpha_2 = 0.5
    else:
      alpha_1 = 0.5
      alpha_2 = 1.5
    beta = 1
    return alpha_1 * information_quantity(vector_1) + alpha_2 * information_quantity(vector_2) - beta * inf_quant_12

  elif sim_fun == 8:
    inf_quant_12 = information_quantity(vector_1) + information_quantity(vector_2) - torch.dot(vector_1, vector_2)
    if information_quantity(vector_1) >= information_quantity(vector_2):
      alpha_1 = 1.5
      alpha_2 = 0.5
    else:
      alpha_1 = 0.5
      alpha_2 = 1.5
    beta = 2
    return alpha_1 * information_quantity(vector_1) + alpha_2 * information_quantity(vector_2) - beta * inf_quant_12

  elif sim_fun == 9:
    inf_quant_12 = information_quantity(vector_1) + information_quantity(vector_2) - torch.dot(vector_1, vector_2)
    if information_quantity(vector_1) >= information_quantity(vector_2):
      alpha_1 = 0.5
      alpha_2 = 1.5
    else:
      alpha_1 = 1.5
      alpha_2 = 0.5
    beta = 1.5
    return alpha_1 * information_quantity(vector_1) + alpha_2 * information_quantity(vector_2) - beta * inf_quant_12

  elif sim_fun == 10:
    inf_quant_12 = information_quantity(vector_1) + information_quantity(vector_2) - torch.dot(vector_1, vector_2)
    if information_quantity(vector_1) >= information_quantity(vector_2):
      alpha_1 = 0.5
      alpha_2 = 1.5
    else:
      alpha_1 = 1.5
      alpha_2 = 0.5
    beta = 0.5
    return alpha_1 * information_quantity(vector_1) + alpha_2 * information_quantity(vector_2) - beta * inf_quant_12

  elif sim_fun == 11:
    inf_quant_12 = information_quantity(vector_1) + information_quantity(vector_2) - torch.dot(vector_1, vector_2)
    if information_quantity(vector_1) >= information_quantity(vector_2):
      alpha_1 = 1.5
      alpha_2 = 1
    else:
      alpha_1 = 1
      alpha_2 = 1.5
    beta = 1.5
    return alpha_1 * information_quantity(vector_1) + alpha_2 * information_quantity(vector_2) - beta * inf_quant_12

# %% [markdown]
# # definition

# %%
rows = ['Constraint 1 - Injectivity', 'Constraint 2 - Zero informativeness', 'Constraint 3 - Infinite informativeness', 'Constraint 4 - Upper and lower bounds',
        'Constraint 5 - Commutativity', 'Constraint 6 - Associativity', 'Constraint 7 - Distributiveness', 'Constraint 8 - Idempotency',
        'Constraint 9 - Identity', 'Constraint 10 - Similarity monotonicity', 'Constraint 11 - Self-similarity', 'Constraint 12 - Asymmetricity', 'Constraint 1 - Injectivity', 'Constraint 2 - Zero informativeness', 'Constraint 3 - Infinite informativeness', 'Constraint 4 - Upper and lower bounds',
        'Constraint 5 - Commutativity', 'Constraint 6 - Associativity', 'Constraint 7 - Distributiveness', 'Constraint 8 - Idempotency',
        'Constraint 9 - Identity', 'Constraint 10 - Similarity monotonicity', 'Constraint 11 - Self-similarity', 'Constraint 12 - Asymmetricity', 'Constraint 1 - Injectivity', 'Constraint 2 - Zero informativeness', 'Constraint 3 - Infinite informativeness', 'Constraint 4 - Upper and lower bounds',
        'Constraint 5 - Commutativity', 'Constraint 6 - Associativity', 'Constraint 7 - Distributiveness', 'Constraint 8 - Idempotency',
        'Constraint 9 - Identity', 'Constraint 10 - Similarity monotonicity', 'Constraint 11 - Self-similarity', 'Constraint 12 - Asymmetricity']

rows_test = ['Test 1 - Sequences', 'Test 2 - Sequences', 'Test 3 - Sequences', 'Test 4 - Sequences', 'Test 5 - Sequences',
             'Test 6 - Sequences', 'Test 7 - Sequences', 'Test 8 - Sequences', 'Test 9 - Sequences', 'Test 10 - Sequences',
             'Test 11 - Sequences', 'Test 12 - Sequences', 'Test 13 - Sequences', 'Test 14 - Sequences', 'Test 15 - Sequences',
             'Test 16 - Sequences', 'Test 17 - Sequences', 'Test 18 - Sequences', 'Test 19 - Sequences', 'Test 20 - Sequences',
             'Test 1 - Ancestors', 'Test 2 - Ancestors', 'Test 3 - Ancestors', 'Test 4 - Ancestors', 'Test 5 - Ancestors',
             'Test 6 - Ancestors', 'Test 7 - Ancestors', 'Test 8 - Ancestors', 'Test 9 - Ancestors', 'Test 10 - Ancestors',
             'Test 11 - Ancestors', 'Test 12 - Ancestors', 'Test 13 - Ancestors', 'Test 14 - Ancestors', 'Test 15 - Ancestors',
             'Test 16 - Ancestors', 'Test 17 - Ancestors', 'Test 21 - Ancestors', 'Test 22 - Ancestors', 'Test 23 - Ancestors',
             'Test 1 - Summaries', 'Test 2 - Summaries', 'Test 3 - Summaries', 'Test 4 - Summaries', 'Test 5 - Summaries',
             'Test 6 - Summaries', 'Test 7 - Summaries', 'Test 8 - Summaries', 'Test 9 - Summaries', 'Test 10 - Summaries',
             'Test 11 - Summaries', 'Test 12 - Summaries', 'Test 13 - Summaries', 'Test 14 - Summaries', 'Test 15 - Summaries',
             'Test 16 - Summaries', 'Test 17 - Summaries', 'Test 24 - Summaries', 'Test 25 - Summaries', 'Test 26 - Summaries']

columns = []
for embed in ['Sum of Vectors', 'Average', 'F_joint', 'F_ind', 'F_inf', 'Norm_avg', 'CLS', 'EOS']: #embedding
  for spec_gen in ['Algebraic','Information','Fuzzy']: #spec and gen functions
    for similarity_function in ['Cosine','Euclidean','Dot','ICM_100_100_150','ICM_150_050_150','ICM_175_075_15','ICM_150_050_100','ICM_150_050_200','ICM_050_150_150','ICM_050_150_050','ICM_150_100_150']: #similarity

      columns.append(embed + " - " + spec_gen + " - " + similarity_function)

results = pd.DataFrame(0, index=rows, columns=columns)

row_result = pd.DataFrame(0, index=rows_test, columns=columns)

# %%
sequences = pd.read_excel('./datasets/sequences.xlsx')
ancestors = pd.read_excel('./datasets/ancestors.xlsx')
summaries = pd.read_excel('./datasets/summaries.xlsx')

# %%
information_quantity(projection(' ', comp_fun='inf'))
# Out:
# tensor(0.)

# %% [markdown]
# # word sequences

# %%
print('Progress: 0%')

q = 0
m = -1
for k in ['sum', 'avg', 'jnt', 'ind', 'inf', 'norm_avg', 'cls', 'eos']: #embedding
  for h in range (3): #spec and gen functions
    h += 1
    for j in range(11): #similarity
      j += 1
      m += 1

      for i in range(len(sequences)):
        q += 1
        vectors = [sequences.iloc[i][0], sequences.iloc[i][1], sequences.iloc[i][2]]
        vectors.sort()

        text_1 = vectors[2]
        text_2 = vectors[1]
        text_3 = vectors[0]

        # given text_1, text_2, text_3
        vector_1 = projection(text_1, comp_fun = k)
        vector_2 = projection(text_2, comp_fun = k)
        vector_3 = projection(text_3, comp_fun = k)
        vector_12 = projection(text_1 + " " + text_2, comp_fun = k)
        vector_123 = projection(text_1 + " " + text_2 + " " + text_3, comp_fun = k)

        # Test 1
        result = test_property(information_quantity(vector_1) != information_quantity(vector_2))
        results.iloc[0][m] += result
        row_result.iloc[0][m] += result

        # Test 2
        result = test_property(information_quantity(projection(" ", comp_fun = k)) == 0)
        results.iloc[1][m] += result
        row_result.iloc[1][m] += result

        # Test 18
        result = test_property(information_quantity(vector_1) < information_quantity(vector_12))
        results.iloc[2][m] += result
        row_result.iloc[17][m] += result

        # Test 19
        result = test_property((information_quantity(vector_1) < information_quantity(specification(vector_1, vector_2, h)) and information_quantity(vector_2) < information_quantity(specification(vector_1, vector_2, h))))
        results.iloc[3][m] += result
        row_result.iloc[18][m] += result

        # Test 20
        result = test_property((information_quantity(vector_1) > information_quantity(generalisation(vector_1, vector_2, h)) and information_quantity(vector_2) > information_quantity(generalisation(vector_1, vector_2, h))))
        results.iloc[3][m] += result
        row_result.iloc[19][m] += result

        # Test 3
        result = test_property((specification(vector_1, vector_2, h) == specification(vector_2, vector_1, h)).all())
        results.iloc[4][m] += result
        row_result.iloc[2][m] += result

        # Test 4
        result = test_property((generalisation(vector_1, vector_2, h) == generalisation(vector_2, vector_1, h)).all())
        results.iloc[4][m] += result
        row_result.iloc[3][m] += result

        # Test 5
        result = test_property((specification(specification(vector_1, vector_2, h), vector_3, h) == specification(vector_1, specification(vector_2, vector_3, h), h)).all())
        results.iloc[5][m] += result
        row_result.iloc[4][m] += result

        # Test 6
        result = test_property((generalisation(generalisation(vector_1, vector_2, h), vector_3, h) == generalisation(vector_1, generalisation(vector_2, vector_3, h), h)).all())
        results.iloc[5][m] += result
        row_result.iloc[5][m] += result

        # Test 7
        result = test_property((specification(generalisation(vector_1, vector_2, h), vector_3, h) == specification(vector_1, generalisation(vector_2, vector_3, h), h)).all())
        results.iloc[6][m] += result
        row_result.iloc[6][m] += result

        # Test 8
        result = test_property((generalisation(specification(vector_1, vector_2, h), vector_3, h) == generalisation(vector_1, specification(vector_2, vector_3, h), h)).all())
        results.iloc[6][m] += result
        row_result.iloc[7][m] += result

        # Test 9
        result = test_property(similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h) , generalisation(vector_1, vector_2, h), j) > similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h) , generalisation(generalisation(vector_1, vector_2, h), vector_3, h), j))
        results.iloc[7][m] += result
        row_result.iloc[8][m] += result

        # Test 10
        result = test_property(similarity(specification(specification(vector_1, vector_2, h), vector_2, h) , specification(vector_1, vector_2, h), j) > similarity(specification(specification(vector_1, vector_2, h), vector_2, h) , specification(specification(vector_1, vector_2, h), vector_3, h), j))
        results.iloc[7][m] += result
        row_result.iloc[9][m] += result

        # Test 11
        result = test_property(similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h) , vector_1, j) > similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h) , vector_2, j))
        results.iloc[8][m] += result
        row_result.iloc[10][m] += result

        # Test 12
        result = test_property(similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h) , vector_1, j) > similarity(specification(specification(vector_1, vector_2, h), vector_1, h) , vector_2, j))
        results.iloc[8][m] += result
        row_result.iloc[11][m] += result

        # Test 13
        result = test_property(similarity(specification(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))
        results.iloc[9][m] += result
        row_result.iloc[12][m] += result

        # Test 14
        result = test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))
        results.iloc[9][m] += result
        row_result.iloc[13][m] += result

        # Test 15
        result = test_property(similarity(vector_1, vector_1, j) > similarity(vector_2, vector_2, j))
        results.iloc[10][m] += result
        row_result.iloc[14][m] += result

        # Test 16
        result = test_property(similarity(vector_1, specification(vector_1, vector_2, h), j) < similarity(specification(vector_1, vector_2, h), vector_1, j))
        results.iloc[11][m] += result
        row_result.iloc[15][m] += result

        # Test 17
        result = test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) < similarity(vector_1, generalisation(vector_1, vector_2, h), j))
        results.iloc[11][m] += result
        row_result.iloc[16][m] += result

        if q % 825 == 0:
          print('Progress: ' + str(round(q *100 /(len(sequences) * 165),2)) + '%')
print('Progress: 100%!')
# Out:
# Progress: 0%
# /tmp/ipykernel_833155/911197093.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   vectors = [sequences.iloc[i][0], sequences.iloc[i][1], sequences.iloc[i][2]]
# /tmp/ipykernel_833155/911197093.py:30: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[0][m] += result
# /tmp/ipykernel_833155/911197093.py:30: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[0][m] += result
# /tmp/ipykernel_833155/911197093.py:31: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[0][m] += result
# /tmp/ipykernel_833155/911197093.py:31: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[0][m] += result
# /tmp/ipykernel_833155/911197093.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[1][m] += result
# /tmp/ipykernel_833155/911197093.py:35: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[1][m] += result
# /tmp/ipykernel_833155/911197093.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[1][m] += result
# /tmp/ipykernel_833155/911197093.py:36: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[1][m] += result
# /tmp/ipykernel_833155/911197093.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[2][m] += result
# /tmp/ipykernel_833155/911197093.py:40: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[2][m] += result
# /tmp/ipykernel_833155/911197093.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[17][m] += result
# /tmp/ipykernel_833155/911197093.py:41: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[17][m] += result
# /tmp/ipykernel_833155/911197093.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[3][m] += result
# /tmp/ipykernel_833155/911197093.py:45: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[3][m] += result
# /tmp/ipykernel_833155/911197093.py:46: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[18][m] += result
# /tmp/ipykernel_833155/911197093.py:46: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[18][m] += result
# /tmp/ipykernel_833155/911197093.py:50: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[3][m] += result
# /tmp/ipykernel_833155/911197093.py:50: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[3][m] += result
# /tmp/ipykernel_833155/911197093.py:51: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[19][m] += result
# /tmp/ipykernel_833155/911197093.py:51: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[19][m] += result
# /tmp/ipykernel_833155/911197093.py:55: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[4][m] += result
# /tmp/ipykernel_833155/911197093.py:55: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[4][m] += result
# /tmp/ipykernel_833155/911197093.py:56: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[2][m] += result
# /tmp/ipykernel_833155/911197093.py:56: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[2][m] += result
# /tmp/ipykernel_833155/911197093.py:60: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[4][m] += result
# /tmp/ipykernel_833155/911197093.py:60: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[4][m] += result
# /tmp/ipykernel_833155/911197093.py:61: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[3][m] += result
# /tmp/ipykernel_833155/911197093.py:61: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[3][m] += result
# /tmp/ipykernel_833155/911197093.py:65: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[5][m] += result
# /tmp/ipykernel_833155/911197093.py:65: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[5][m] += result
# /tmp/ipykernel_833155/911197093.py:66: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[4][m] += result
# /tmp/ipykernel_833155/911197093.py:66: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[4][m] += result
# /tmp/ipykernel_833155/911197093.py:70: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[5][m] += result
# /tmp/ipykernel_833155/911197093.py:70: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[5][m] += result
# /tmp/ipykernel_833155/911197093.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[5][m] += result
# /tmp/ipykernel_833155/911197093.py:71: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[5][m] += result
# /tmp/ipykernel_833155/911197093.py:75: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[6][m] += result
# /tmp/ipykernel_833155/911197093.py:75: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[6][m] += result
# /tmp/ipykernel_833155/911197093.py:76: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[6][m] += result
# /tmp/ipykernel_833155/911197093.py:76: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[6][m] += result
# /tmp/ipykernel_833155/911197093.py:80: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[6][m] += result
# /tmp/ipykernel_833155/911197093.py:80: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[6][m] += result
# /tmp/ipykernel_833155/911197093.py:81: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[7][m] += result
# /tmp/ipykernel_833155/911197093.py:81: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[7][m] += result
# /tmp/ipykernel_833155/911197093.py:85: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[7][m] += result
# /tmp/ipykernel_833155/911197093.py:85: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[7][m] += result
# /tmp/ipykernel_833155/911197093.py:86: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[8][m] += result
# /tmp/ipykernel_833155/911197093.py:86: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[8][m] += result
# /tmp/ipykernel_833155/911197093.py:90: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[7][m] += result
# /tmp/ipykernel_833155/911197093.py:90: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[7][m] += result
# /tmp/ipykernel_833155/911197093.py:91: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[9][m] += result
# /tmp/ipykernel_833155/911197093.py:91: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[9][m] += result
# /tmp/ipykernel_833155/911197093.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[8][m] += result
# /tmp/ipykernel_833155/911197093.py:95: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[8][m] += result
# /tmp/ipykernel_833155/911197093.py:96: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[10][m] += result
# /tmp/ipykernel_833155/911197093.py:96: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[10][m] += result
# /tmp/ipykernel_833155/911197093.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[8][m] += result
# /tmp/ipykernel_833155/911197093.py:100: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[8][m] += result
# /tmp/ipykernel_833155/911197093.py:101: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[11][m] += result
# /tmp/ipykernel_833155/911197093.py:101: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[11][m] += result
# /tmp/ipykernel_833155/911197093.py:105: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[9][m] += result
# /tmp/ipykernel_833155/911197093.py:105: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[9][m] += result
# /tmp/ipykernel_833155/911197093.py:106: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[12][m] += result
# /tmp/ipykernel_833155/911197093.py:106: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[12][m] += result
# /tmp/ipykernel_833155/911197093.py:110: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[9][m] += result
# /tmp/ipykernel_833155/911197093.py:110: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[9][m] += result
# /tmp/ipykernel_833155/911197093.py:111: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[13][m] += result
# /tmp/ipykernel_833155/911197093.py:111: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[13][m] += result
# /tmp/ipykernel_833155/911197093.py:115: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[10][m] += result
# /tmp/ipykernel_833155/911197093.py:115: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[10][m] += result
# /tmp/ipykernel_833155/911197093.py:116: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[14][m] += result
# /tmp/ipykernel_833155/911197093.py:116: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[14][m] += result
# /tmp/ipykernel_833155/911197093.py:120: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[11][m] += result
# /tmp/ipykernel_833155/911197093.py:120: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[11][m] += result
# /tmp/ipykernel_833155/911197093.py:121: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[15][m] += result
# /tmp/ipykernel_833155/911197093.py:121: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[15][m] += result
# /tmp/ipykernel_833155/911197093.py:125: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[11][m] += result
# /tmp/ipykernel_833155/911197093.py:125: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[11][m] += result
# /tmp/ipykernel_833155/911197093.py:126: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[16][m] += result
# /tmp/ipykernel_833155/911197093.py:126: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[16][m] += result
# /opt/conda/lib/python3.10/site-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Progress: 5.0%
# Progress: 10.0%
# Progress: 15.0%
# Progress: 20.0%
# Progress: 25.0%
# Progress: 30.0%
# Progress: 35.0%
# Progress: 40.0%
# Progress: 45.0%
# Progress: 50.0%
# Progress: 55.0%
# Progress: 60.0%
# Progress: 65.0%
# Progress: 70.0%
# Progress: 75.0%
# Progress: 80.0%
# Progress: 85.0%
# Progress: 90.0%
# Progress: 95.0%
# Progress: 100.0%
# Progress: 100%!

# %% [markdown]
# # ancestors

# %%
print('Progress: 0%')

q = 0
m = -1
for k in ['sum', 'avg', 'jnt', 'ind', 'inf', 'norm_avg', 'cls', 'eos']: #embedding
  for h in range (3): #spec and gen functions
    h += 1
    for j in range(11): #similarity
      j += 1
      m += 1
      for i in range(len(ancestors)):
        q += 1
        text_1 = ancestors.iloc[i][0] # w
        text_1b = ancestors.iloc[i][1] # w'
        text_2 = ancestors.iloc[i][2] # ancestor w_a
        text_3 = ancestors.iloc[i][3] # ancestor w_aa

        # given text_1, text_2, text_3
        vector_1 = projection(text_1, comp_fun = k)
        vector_1b = projection(text_1b, comp_fun = k)
        vector_2 = projection(text_2, comp_fun = k)
        vector_3 = projection(text_3, comp_fun = k)
        vector_n = projection('cheese',comp_fun = k)

        # Test 1
        result = test_property(information_quantity(vector_1) != information_quantity(vector_2))
        results.iloc[12][m] += result
        row_result.iloc[20][m] += result

        # Test 2
        result = test_property(information_quantity(projection(" ",comp_fun = k)) == 0)
        results.iloc[13][m] += result
        row_result.iloc[21][m] += result

        # Test 21
        result = test_property(information_quantity(vector_2) != information_quantity(vector_1))
        results.iloc[14][m] += result
        row_result.iloc[37][m] += result

        # Test 22
        result = test_property(information_quantity(generalisation(vector_1,vector_2, h)) < information_quantity(generalisation(vector_1,vector_n, h)))
        results.iloc[15][m] += result
        row_result.iloc[38][m] += result

        # Test 23
        result = test_property(information_quantity(specification(vector_1,vector_2, h)) > information_quantity(specification(vector_1,vector_n, h)))
        results.iloc[15][m] += result
        row_result.iloc[39][m] += result

        # Test 3
        result = test_property((specification(vector_1, vector_2, h) == specification(vector_2, vector_1, h)).all())
        results.iloc[16][m] += result
        row_result.iloc[22][m] += result

        # Test 4
        result = test_property((generalisation(vector_1, vector_2, h) == generalisation(vector_2, vector_1, h)).all())
        results.iloc[16][m] += result
        row_result.iloc[23][m] += result

        # Test 5
        result = test_property((specification(specification(vector_1, vector_2, h), vector_1b, h) == specification(vector_1, specification(vector_2, vector_1b, h), h)).all())
        results.iloc[0][m] += result
        row_result.iloc[24][m] += result

        # Test 6
        result = test_property((generalisation(generalisation(vector_1, vector_2, h), vector_1b, h) == generalisation(vector_1, generalisation(vector_2, vector_1b, h), h)).all())
        results.iloc[17][m] += result
        row_result.iloc[25][m] += result

        # Test 7
        result = test_property((specification(generalisation(vector_1, vector_2, h), vector_1b, h) == specification(vector_1, generalisation(vector_2, vector_1b, h), h)).all())
        results.iloc[18][m] += result
        row_result.iloc[26][m] += result

        # Test 8
        result = test_property((generalisation(specification(vector_1, vector_2, h), vector_1b, h) == generalisation(vector_1, specification(vector_2, vector_1b, h), h)).all())
        results.iloc[18][m] += result
        row_result.iloc[27][m] += result

        # Test 9
        result = test_property(similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h), generalisation(vector_1, vector_2, h), j) > similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h) , generalisation(generalisation(vector_1, vector_2, h), vector_3, h), j))
        results.iloc[19][m] += result
        row_result.iloc[28][m] += result

        # Test 10
        result = test_property(similarity(specification(specification(vector_1, vector_2, h), vector_2, h), specification(vector_1, vector_2, h), j) > similarity(specification(specification(vector_1, vector_2, h), vector_2, h) , specification(specification(vector_1, vector_2, h), vector_3, h), j))
        results.iloc[19][m] += result
        row_result.iloc[29][m] += result

        # Test 11
        result = test_property(similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h), vector_1, j) > similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h) , vector_2, j))
        results.iloc[20][m] += result
        row_result.iloc[30][m] += result

        # Test 12
        result = test_property(similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h), vector_1, j) > similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h) , vector_2, j))
        results.iloc[20][m] += result
        row_result.iloc[31][m] += result

        # Test 13
        result = test_property(similarity(specification(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))
        results.iloc[21][m] += result
        row_result.iloc[32][m] += result

        # Test 14
        result = test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))
        results.iloc[21][m] += result
        row_result.iloc[33][m] += result

        # Test 15
        result = test_property(similarity(vector_1, vector_1, j) > similarity(vector_2, vector_2, j))
        results.iloc[22][m] += result
        row_result.iloc[34][m] += result

        # Test 16
        result = test_property(similarity(vector_1, specification(vector_1, vector_2, h), j) < similarity(specification(vector_1, vector_2, h), vector_1, j))
        results.iloc[23][m] += result
        row_result.iloc[35][m] += result

        # Test 17
        result = test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) < similarity(vector_1, generalisation(vector_1, vector_2, h), j))
        results.iloc[23][m] += result
        row_result.iloc[36][m] += result

        if q % 780 == 0:
          print('Progress: ' + str(round(q *100 /(len(ancestors) * 165),2)) + '%')
print('Progress: 100%!')
# Out:
# Progress: 0%
# /tmp/ipykernel_833155/1492011083.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text_1 = ancestors.iloc[i][0] # w
# /tmp/ipykernel_833155/1492011083.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text_1b = ancestors.iloc[i][1] # w'
# /tmp/ipykernel_833155/1492011083.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text_2 = ancestors.iloc[i][2] # ancestor w_a
# /tmp/ipykernel_833155/1492011083.py:16: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text_3 = ancestors.iloc[i][3] # ancestor w_aa
# /tmp/ipykernel_833155/1492011083.py:27: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[12][m] += result
# /tmp/ipykernel_833155/1492011083.py:27: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[12][m] += result
# /tmp/ipykernel_833155/1492011083.py:28: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[20][m] += result
# /tmp/ipykernel_833155/1492011083.py:28: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[20][m] += result
# /tmp/ipykernel_833155/1492011083.py:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[13][m] += result
# /tmp/ipykernel_833155/1492011083.py:32: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[13][m] += result
# /tmp/ipykernel_833155/1492011083.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[21][m] += result
# /tmp/ipykernel_833155/1492011083.py:33: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[21][m] += result
# /tmp/ipykernel_833155/1492011083.py:37: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[14][m] += result
# /tmp/ipykernel_833155/1492011083.py:37: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[14][m] += result
# /tmp/ipykernel_833155/1492011083.py:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[37][m] += result
# /tmp/ipykernel_833155/1492011083.py:38: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[37][m] += result
# /tmp/ipykernel_833155/1492011083.py:42: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[15][m] += result
# /tmp/ipykernel_833155/1492011083.py:42: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[15][m] += result
# /tmp/ipykernel_833155/1492011083.py:43: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[38][m] += result
# /tmp/ipykernel_833155/1492011083.py:43: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[38][m] += result
# /tmp/ipykernel_833155/1492011083.py:47: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[15][m] += result
# /tmp/ipykernel_833155/1492011083.py:47: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[15][m] += result
# /tmp/ipykernel_833155/1492011083.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[39][m] += result
# /tmp/ipykernel_833155/1492011083.py:48: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[39][m] += result
# /tmp/ipykernel_833155/1492011083.py:52: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[16][m] += result
# /tmp/ipykernel_833155/1492011083.py:52: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[16][m] += result
# /tmp/ipykernel_833155/1492011083.py:53: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[22][m] += result
# /tmp/ipykernel_833155/1492011083.py:53: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[22][m] += result
# /tmp/ipykernel_833155/1492011083.py:57: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[16][m] += result
# /tmp/ipykernel_833155/1492011083.py:57: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[16][m] += result
# /tmp/ipykernel_833155/1492011083.py:58: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[23][m] += result
# /tmp/ipykernel_833155/1492011083.py:58: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[23][m] += result
# /tmp/ipykernel_833155/1492011083.py:62: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[0][m] += result
# /tmp/ipykernel_833155/1492011083.py:62: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[0][m] += result
# /tmp/ipykernel_833155/1492011083.py:63: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[24][m] += result
# /tmp/ipykernel_833155/1492011083.py:63: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[24][m] += result
# /tmp/ipykernel_833155/1492011083.py:67: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[17][m] += result
# /tmp/ipykernel_833155/1492011083.py:67: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[17][m] += result
# /tmp/ipykernel_833155/1492011083.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[25][m] += result
# /tmp/ipykernel_833155/1492011083.py:68: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[25][m] += result
# /tmp/ipykernel_833155/1492011083.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[18][m] += result
# /tmp/ipykernel_833155/1492011083.py:72: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[18][m] += result
# /tmp/ipykernel_833155/1492011083.py:73: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[26][m] += result
# /tmp/ipykernel_833155/1492011083.py:73: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[26][m] += result
# /tmp/ipykernel_833155/1492011083.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[18][m] += result
# /tmp/ipykernel_833155/1492011083.py:77: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[18][m] += result
# /tmp/ipykernel_833155/1492011083.py:78: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[27][m] += result
# /tmp/ipykernel_833155/1492011083.py:78: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[27][m] += result
# /tmp/ipykernel_833155/1492011083.py:82: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[19][m] += result
# /tmp/ipykernel_833155/1492011083.py:82: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[19][m] += result
# /tmp/ipykernel_833155/1492011083.py:83: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[28][m] += result
# /tmp/ipykernel_833155/1492011083.py:83: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[28][m] += result
# /tmp/ipykernel_833155/1492011083.py:87: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[19][m] += result
# /tmp/ipykernel_833155/1492011083.py:87: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[19][m] += result
# /tmp/ipykernel_833155/1492011083.py:88: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[29][m] += result
# /tmp/ipykernel_833155/1492011083.py:88: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[29][m] += result
# /tmp/ipykernel_833155/1492011083.py:92: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[20][m] += result
# /tmp/ipykernel_833155/1492011083.py:92: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[20][m] += result
# /tmp/ipykernel_833155/1492011083.py:93: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[30][m] += result
# /tmp/ipykernel_833155/1492011083.py:93: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[30][m] += result
# /tmp/ipykernel_833155/1492011083.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[20][m] += result
# /tmp/ipykernel_833155/1492011083.py:97: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[20][m] += result
# /tmp/ipykernel_833155/1492011083.py:98: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[31][m] += result
# /tmp/ipykernel_833155/1492011083.py:98: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[31][m] += result
# /tmp/ipykernel_833155/1492011083.py:102: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[21][m] += result
# /tmp/ipykernel_833155/1492011083.py:102: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[21][m] += result
# /tmp/ipykernel_833155/1492011083.py:103: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[32][m] += result
# /tmp/ipykernel_833155/1492011083.py:103: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[32][m] += result
# /tmp/ipykernel_833155/1492011083.py:107: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[21][m] += result
# /tmp/ipykernel_833155/1492011083.py:107: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[21][m] += result
# /tmp/ipykernel_833155/1492011083.py:108: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[33][m] += result
# /tmp/ipykernel_833155/1492011083.py:108: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[33][m] += result
# /tmp/ipykernel_833155/1492011083.py:112: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[22][m] += result
# /tmp/ipykernel_833155/1492011083.py:112: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[22][m] += result
# /tmp/ipykernel_833155/1492011083.py:113: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[34][m] += result
# /tmp/ipykernel_833155/1492011083.py:113: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[34][m] += result
# /tmp/ipykernel_833155/1492011083.py:117: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[23][m] += result
# /tmp/ipykernel_833155/1492011083.py:117: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[23][m] += result
# /tmp/ipykernel_833155/1492011083.py:118: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[35][m] += result
# /tmp/ipykernel_833155/1492011083.py:118: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[35][m] += result
# /tmp/ipykernel_833155/1492011083.py:122: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[23][m] += result
# /tmp/ipykernel_833155/1492011083.py:122: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[23][m] += result
# /tmp/ipykernel_833155/1492011083.py:123: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[36][m] += result
# /tmp/ipykernel_833155/1492011083.py:123: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[36][m] += result
# Progress: 4.73%
# Progress: 9.45%
# Progress: 14.18%
# Progress: 18.91%
# Progress: 23.64%
# Progress: 28.36%
# Progress: 33.09%
# Progress: 37.82%
# Progress: 42.55%
# Progress: 47.27%
# Progress: 52.0%
# Progress: 56.73%
# Progress: 61.45%
# Progress: 66.18%
# Progress: 70.91%
# Progress: 75.64%
# Progress: 80.36%
# Progress: 85.09%
# Progress: 89.82%
# Progress: 94.55%
# Progress: 99.27%
# Progress: 100%!

# %% [markdown]
# # summaries

# %%
print('Progress: 0%')

q = 0
m = -1
for k in ['sum', 'avg', 'jnt', 'ind', 'inf', 'norm_avg', 'cls', 'eos']: #embedding
  for h in range (3): #spec and gen functions
    h += 1
    for j in range(11): #similarity
      j += 1
      m += 1
      for i in range(len(summaries)):
        q += 1
        text_1 = summaries.iloc[i][0] # r
        text_2 = summaries.iloc[i][1] # r_1
        text_3 = summaries.iloc[i][2] # r_2

        # given text_1, text_2, text_3
        vector_1 = projection(text_1, comp_fun = k)
        vector_2 = projection(text_2, comp_fun = k)
        vector_3 = projection(text_3, comp_fun = k)

         # Test 1
        result = test_property(information_quantity(vector_1) != information_quantity(vector_2))
        results.iloc[24][m] += result
        row_result.iloc[40][m] += result

        # Test 2
        result = test_property(information_quantity(projection(" ", comp_fun = k)) == 0)
        results.iloc[25][m] += result
        row_result.iloc[41][m] += result

        # Test 24
        result = test_property(information_quantity(vector_2) < information_quantity(vector_1))
        results.iloc[26][m] += result
        row_result.iloc[57][m] += result

        # Test 25
        result = test_property((information_quantity(vector_1) < information_quantity(specification(vector_1, vector_2, h)) and information_quantity(vector_2) < information_quantity(specification(vector_1, vector_2, h))))
        results.iloc[27][m] += result
        row_result.iloc[58][m] += result

        # Test 26
        result = test_property((information_quantity(vector_1) > information_quantity(generalisation(vector_1, vector_2, h)) and information_quantity(vector_2) > information_quantity(generalisation(vector_1, vector_2, h))))
        results.iloc[27][m] += result
        row_result.iloc[59][m] += result

        # Test 3
        result = test_property((specification(vector_1, vector_2, h) == specification(vector_2, vector_1, h)).all())
        results.iloc[28][m] += result
        row_result.iloc[42][m] += result

        # Test 4
        result = test_property((generalisation(vector_1, vector_2, h) == generalisation(vector_2, vector_1, h)).all())
        results.iloc[28][m] += result
        row_result.iloc[43][m] += result

        # Test 5
        result = test_property((specification(specification(vector_1, vector_2, h), vector_1b, h) == specification(vector_1, specification(vector_2, vector_1b, h), h)).all())
        results.iloc[29][m] += result
        row_result.iloc[44][m] += result

        # Test 6
        result = test_property((generalisation(generalisation(vector_1, vector_2, h), vector_1b, h) == generalisation(vector_1, generalisation(vector_2, vector_1b, h), h)).all())
        results.iloc[29][m] += result
        row_result.iloc[45][m] += result

        # Test 7
        result = test_property((specification(generalisation(vector_1, vector_2, h), vector_1b, h) == specification(vector_1, generalisation(vector_2, vector_1b, h), h)).all())
        results.iloc[30][m] += result
        row_result.iloc[46][m] += result

        # Test 8
        result = test_property((generalisation(specification(vector_1, vector_2, h), vector_1b, h) == generalisation(vector_1, specification(vector_2, vector_1b, h), h)).all())
        results.iloc[30][m] += result
        row_result.iloc[47][m] += result

        # Test 9
        result = test_property(similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h), generalisation(vector_1, vector_2, h), j) > similarity(generalisation(generalisation(vector_1, vector_2, h), vector_1, h) , generalisation(generalisation(vector_1, vector_2, h), vector_3, h), j))
        results.iloc[31][m] += result
        row_result.iloc[48][m] += result

        # Test 10
        result = test_property(similarity(specification(specification(vector_1, vector_2, h), vector_2, h), specification(vector_1, vector_2, h), j) > similarity(specification(specification(vector_1, vector_2, h), vector_2, h) , specification(specification(vector_1, vector_2, h), vector_3, h), j))
        results.iloc[31][m] += result
        row_result.iloc[49][m] += result

        # Test 11
        result = test_property(similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h), vector_1, j) > similarity(specification(generalisation(vector_1, vector_2, h), vector_1, h) , vector_2, j))
        results.iloc[32][m] += result
        row_result.iloc[50][m] += result

        # Test 12
        result = test_property(similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h), vector_1, j) > similarity(generalisation(specification(vector_1, vector_2, h), vector_1, h) , vector_2, j))
        results.iloc[32][m] += result
        row_result.iloc[51][m] += result

        # Test 13
        result = test_property(similarity(specification(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))
        results.iloc[33][m] += result
        row_result.iloc[52][m] += result

        # Test 14
        result = test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) > similarity(vector_1, vector_2, j))
        results.iloc[33][m] += result
        row_result.iloc[53][m] += result

        # Test 15
        result = test_property(similarity(vector_1, vector_1, j) > similarity(vector_2, vector_2, j))
        results.iloc[34][m] += result
        row_result.iloc[54][m] += result

        # Test 16
        result = test_property(similarity(vector_1, specification(vector_1, vector_2, h), j) < similarity(specification(vector_1, vector_2, h), vector_1, j))
        results.iloc[35][m] += result
        row_result.iloc[55][m] += result

        # Test 17
        result = test_property(similarity(generalisation(vector_1, vector_2, h), vector_1, j) < similarity(vector_1, generalisation(vector_1, vector_2, h), j))
        results.iloc[35][m] += result
        row_result.iloc[56][m] += result

        if q % 350 == 0:
          print('Progress: ' + str(round(q *100 /(len(summaries) * 165),2)) + '%')
print('Progress: 100%!')
# Out:
# Progress: 0%
# /tmp/ipykernel_833155/37093893.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text_1 = summaries.iloc[i][0] # r
# /tmp/ipykernel_833155/37093893.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text_2 = summaries.iloc[i][1] # r_1
# /tmp/ipykernel_833155/37093893.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   text_3 = summaries.iloc[i][2] # r_2
# /tmp/ipykernel_833155/37093893.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[24][m] += result
# /tmp/ipykernel_833155/37093893.py:24: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[24][m] += result
# /tmp/ipykernel_833155/37093893.py:25: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[40][m] += result
# /tmp/ipykernel_833155/37093893.py:25: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[40][m] += result
# /tmp/ipykernel_833155/37093893.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[25][m] += result
# /tmp/ipykernel_833155/37093893.py:29: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[25][m] += result
# /tmp/ipykernel_833155/37093893.py:30: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[41][m] += result
# /tmp/ipykernel_833155/37093893.py:30: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[41][m] += result
# /tmp/ipykernel_833155/37093893.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[26][m] += result
# /tmp/ipykernel_833155/37093893.py:34: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[26][m] += result
# /tmp/ipykernel_833155/37093893.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[57][m] += result
# /tmp/ipykernel_833155/37093893.py:35: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[57][m] += result
# /tmp/ipykernel_833155/37093893.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[27][m] += result
# /tmp/ipykernel_833155/37093893.py:39: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[27][m] += result
# /tmp/ipykernel_833155/37093893.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[58][m] += result
# /tmp/ipykernel_833155/37093893.py:40: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[58][m] += result
# /tmp/ipykernel_833155/37093893.py:44: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[27][m] += result
# /tmp/ipykernel_833155/37093893.py:44: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[27][m] += result
# /tmp/ipykernel_833155/37093893.py:45: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[59][m] += result
# /tmp/ipykernel_833155/37093893.py:45: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[59][m] += result
# /tmp/ipykernel_833155/37093893.py:49: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[28][m] += result
# /tmp/ipykernel_833155/37093893.py:49: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[28][m] += result
# /tmp/ipykernel_833155/37093893.py:50: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[42][m] += result
# /tmp/ipykernel_833155/37093893.py:50: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[42][m] += result
# /tmp/ipykernel_833155/37093893.py:54: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[28][m] += result
# /tmp/ipykernel_833155/37093893.py:54: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[28][m] += result
# /tmp/ipykernel_833155/37093893.py:55: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[43][m] += result
# /tmp/ipykernel_833155/37093893.py:55: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[43][m] += result
# /tmp/ipykernel_833155/37093893.py:59: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[29][m] += result
# /tmp/ipykernel_833155/37093893.py:59: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[29][m] += result
# /tmp/ipykernel_833155/37093893.py:60: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[44][m] += result
# /tmp/ipykernel_833155/37093893.py:60: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[44][m] += result
# /tmp/ipykernel_833155/37093893.py:64: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[29][m] += result
# /tmp/ipykernel_833155/37093893.py:64: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[29][m] += result
# /tmp/ipykernel_833155/37093893.py:65: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[45][m] += result
# /tmp/ipykernel_833155/37093893.py:65: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[45][m] += result
# /tmp/ipykernel_833155/37093893.py:69: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[30][m] += result
# /tmp/ipykernel_833155/37093893.py:69: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[30][m] += result
# /tmp/ipykernel_833155/37093893.py:70: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[46][m] += result
# /tmp/ipykernel_833155/37093893.py:70: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[46][m] += result
# /tmp/ipykernel_833155/37093893.py:74: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[30][m] += result
# /tmp/ipykernel_833155/37093893.py:74: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[30][m] += result
# /tmp/ipykernel_833155/37093893.py:75: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[47][m] += result
# /tmp/ipykernel_833155/37093893.py:75: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[47][m] += result
# /tmp/ipykernel_833155/37093893.py:79: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[31][m] += result
# /tmp/ipykernel_833155/37093893.py:79: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[31][m] += result
# /tmp/ipykernel_833155/37093893.py:80: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[48][m] += result
# /tmp/ipykernel_833155/37093893.py:80: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[48][m] += result
# /tmp/ipykernel_833155/37093893.py:84: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[31][m] += result
# /tmp/ipykernel_833155/37093893.py:84: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[31][m] += result
# /tmp/ipykernel_833155/37093893.py:85: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[49][m] += result
# /tmp/ipykernel_833155/37093893.py:85: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[49][m] += result
# /tmp/ipykernel_833155/37093893.py:89: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[32][m] += result
# /tmp/ipykernel_833155/37093893.py:89: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[32][m] += result
# /tmp/ipykernel_833155/37093893.py:90: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[50][m] += result
# /tmp/ipykernel_833155/37093893.py:90: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[50][m] += result
# /tmp/ipykernel_833155/37093893.py:94: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[32][m] += result
# /tmp/ipykernel_833155/37093893.py:94: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[32][m] += result
# /tmp/ipykernel_833155/37093893.py:95: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[51][m] += result
# /tmp/ipykernel_833155/37093893.py:95: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[51][m] += result
# /tmp/ipykernel_833155/37093893.py:99: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[33][m] += result
# /tmp/ipykernel_833155/37093893.py:99: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[33][m] += result
# /tmp/ipykernel_833155/37093893.py:100: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[52][m] += result
# /tmp/ipykernel_833155/37093893.py:100: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[52][m] += result
# /tmp/ipykernel_833155/37093893.py:104: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[33][m] += result
# /tmp/ipykernel_833155/37093893.py:104: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[33][m] += result
# /tmp/ipykernel_833155/37093893.py:105: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[53][m] += result
# /tmp/ipykernel_833155/37093893.py:105: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[53][m] += result
# /tmp/ipykernel_833155/37093893.py:109: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[34][m] += result
# /tmp/ipykernel_833155/37093893.py:109: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[34][m] += result
# /tmp/ipykernel_833155/37093893.py:110: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[54][m] += result
# /tmp/ipykernel_833155/37093893.py:110: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[54][m] += result
# /tmp/ipykernel_833155/37093893.py:114: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[35][m] += result
# /tmp/ipykernel_833155/37093893.py:114: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[35][m] += result
# /tmp/ipykernel_833155/37093893.py:115: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[55][m] += result
# /tmp/ipykernel_833155/37093893.py:115: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[55][m] += result
# /tmp/ipykernel_833155/37093893.py:119: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   results.iloc[35][m] += result
# /tmp/ipykernel_833155/37093893.py:119: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   results.iloc[35][m] += result
# /tmp/ipykernel_833155/37093893.py:120: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   row_result.iloc[56][m] += result
# /tmp/ipykernel_833155/37093893.py:120: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   row_result.iloc[56][m] += result
# Progress: 4.24%
# Progress: 8.48%
# Progress: 12.73%
# Progress: 16.97%
# Progress: 21.21%
# Progress: 25.45%
# Progress: 29.7%
# Progress: 33.94%
# Progress: 38.18%
# Progress: 42.42%
# Progress: 46.67%
# Progress: 50.91%
# Progress: 55.15%
# Progress: 59.39%
# Progress: 63.64%
# Progress: 67.88%
# Progress: 72.12%
# Progress: 76.36%
# Progress: 80.61%
# Progress: 84.85%
# Progress: 89.09%
# Progress: 93.33%
# Progress: 97.58%
# Progress: 100%!

# %% [markdown]
# # Results comparison

# %%
test_number = [1, 1, 1, 2, 2, 2, 2, 2, 2, 2, 1, 2]
sequence_normalizer = [x * len(sequences) for x in test_number]
ancestors_normalizer = [x * len(ancestors) for x in test_number]
summaries_normalizer = [x * len(summaries) for x in test_number]
normalizer = sequence_normalizer + ancestors_normalizer + summaries_normalizer
normalized_results = results.div(normalizer, axis=0).round(2)

row_sequence_normalizer = [len(sequences) for x in range(20)]
row_ancestors_normalizer = [len(ancestors) for x in range(20)]
row_summaries_normalizer = [len(summaries) for x in range(20)]
row_normalizer = row_sequence_normalizer + row_ancestors_normalizer + row_summaries_normalizer
row_normalized_results = row_result.div(row_normalizer, axis=0).round(2)

# %%
normalized_results.to_csv('./results/normalized_results.csv')
row_normalized_results.to_csv('./results//normalized_results_tests.csv')

# %%
groups = [normalized_results.iloc[i:i+12] for i in range(0, len(normalized_results), 12)]

sums = [group.sum() for group in groups]

sums_df = pd.concat(sums, axis=1, keys=[f'Group_{i+1}' for i in range(len(groups))])

total_sum = normalized_results.sum()
sums_df['Total_Sum'] = total_sum

# %%
analysis_df = sums_df['Total_Sum']

# %% [markdown]
# # Embedding analysis

# %%
# Dividir la columna en segmentos de 33 elementos cada uno
segmentos = [analysis_df.iloc[i:i+33].reset_index(drop=True) for i in range(0, len(analysis_df), 33)]

# Crear un nuevo DataFrame con las columnas deseadas
nuevo_df = pd.concat(segmentos, axis=1, ignore_index=True)

nuevo_df.columns = ['Sum of Vectors', 'Average', 'F_joint', 'F_ind', 'F_inf', 'Norm_avg', 'CLS', 'EOS']

# Nombrar las filas del nuevo DataFrame
nuevo_df.index = ['Algebraic - Cosine',
'Algebraic - Euclidean',
'Algebraic - Dot',
'Algebraic - ICM_100_100_150',
'Algebraic - ICM_150_050_150',
'Algebraic - ICM_175_075_15',
'Algebraic - ICM_150_050_100',
'Algebraic - ICM_150_050_200',
'Algebraic - ICM_050_150_150',
'Algebraic - ICM_050_150_050',
'Algebraic - ICM_150_100_150',
'Information - Cosine',
'Information - Euclidean',
'Information - Dot',
'Information - ICM_100_100_150',
'Information - ICM_150_050_150',
'Information - ICM_175_075_15',
'Information - ICM_150_050_100',
'Information - ICM_150_050_200',
'Information - ICM_050_150_150',
'Information - ICM_050_150_050',
'Information - ICM_150_100_150',
'Fuzzy - Cosine',
'Fuzzy - Euclidean',
'Fuzzy - Dot',
'Fuzzy - ICM_100_100_150',
'Fuzzy - ICM_150_050_150',
'Fuzzy - ICM_175_075_15',
'Fuzzy - ICM_150_050_100',
'Fuzzy - ICM_150_050_200',
'Fuzzy - ICM_050_150_150',
'Fuzzy - ICM_050_150_050',
'Fuzzy - ICM_150_100_150'  ]

latex_table = nuevo_df.to_latex()
print(latex_table)
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
#  & Sum of Vectors & Average & F_joint & F_ind & F_inf \\
# \midrule
# Algebraic - Cosine & 20.990000 & 21.830000 & 21.980000 & 20.530000 & 20.910000 \\
# Algebraic - Euclidean & 17.700000 & 16.690000 & 17.440000 & 17.070000 & 17.400000 \\
# Algebraic - Dot & 23.630000 & 20.710000 & 22.020000 & 22.580000 & 22.780000 \\
# Algebraic - ICM_100_100_150 & 24.720000 & 22.890000 & 24.060000 & 23.970000 & 24.380000 \\
# Algebraic - ICM_150_050_150 & 25.460000 & 23.960000 & 25.200000 & 25.020000 & 25.450000 \\
# Algebraic - ICM_175_075_15 & 24.140000 & 22.510000 & 23.710000 & 23.470000 & 23.910000 \\
# Algebraic - ICM_150_050_100 & 24.110000 & 22.430000 & 23.600000 & 23.380000 & 23.800000 \\
# Algebraic - ICM_150_050_200 & 24.000000 & 22.570000 & 23.420000 & 23.140000 & 23.530000 \\
# Algebraic - ICM_050_150_150 & 23.900000 & 20.060000 & 21.380000 & 22.430000 & 22.330000 \\
# Algebraic - ICM_050_150_050 & 23.500000 & 20.230000 & 21.610000 & 22.370000 & 22.370000 \\
# Algebraic - ICM_150_100_150 & 24.170000 & 22.210000 & 23.490000 & 23.390000 & 23.790000 \\
# Information - Cosine & 21.220000 & 22.970000 & 23.360000 & 21.750000 & 22.220000 \\
# Information - Euclidean & 14.320000 & 12.960000 & 13.990000 & 14.320000 & 14.320000 \\
# Information - Dot & 23.600000 & 22.320000 & 23.850000 & 23.900000 & 24.230000 \\
# Information - ICM_100_100_150 & 25.040000 & 23.560000 & 24.870000 & 25.240000 & 25.330000 \\
# Information - ICM_150_050_150 & 24.340000 & 23.140000 & 24.690000 & 24.690000 & 25.060000 \\
# Information - ICM_175_075_15 & 24.120000 & 22.450000 & 24.200000 & 24.310000 & 24.680000 \\
# Information - ICM_150_050_100 & 23.790000 & 21.690000 & 23.310000 & 23.800000 & 24.040000 \\
# Information - ICM_150_050_200 & 22.380000 & 21.930000 & 22.980000 & 22.690000 & 23.000000 \\
# Information - ICM_050_150_150 & 24.760000 & 23.580000 & 24.830000 & 25.000000 & 25.190000 \\
# Information - ICM_050_150_050 & 21.940000 & 19.990000 & 21.630000 & 22.030000 & 22.150000 \\
# Information - ICM_150_100_150 & 24.060000 & 22.750000 & 24.450000 & 24.490000 & 24.760000 \\
# Fuzzy - Cosine & 24.180000 & 24.900000 & 25.540000 & 24.390000 & 24.720000 \\
# Fuzzy - Euclidean & 17.680000 & 16.320000 & 17.370000 & 17.680000 & 17.680000 \\
# Fuzzy - Dot & 26.550000 & 24.120000 & 25.580000 & 26.340000 & 26.320000 \\
# Fuzzy - ICM_100_100_150 & 28.620000 & 26.520000 & 28.160000 & 28.650000 & 28.710000 \\
# Fuzzy - ICM_150_050_150 & 27.280000 & 25.310000 & 26.890000 & 27.350000 & 27.450000 \\
# Fuzzy - ICM_175_075_15 & 26.800000 & 24.730000 & 26.400000 & 26.750000 & 26.870000 \\
# Fuzzy - ICM_150_050_100 & 26.490000 & 24.240000 & 26.000000 & 26.420000 & 26.550000 \\
# Fuzzy - ICM_150_050_200 & 25.650000 & 24.690000 & 26.080000 & 25.860000 & 26.170000 \\
# Fuzzy - ICM_050_150_150 & 27.870000 & 25.660000 & 27.220000 & 27.760000 & 27.810000 \\
# Fuzzy - ICM_050_150_050 & 26.160000 & 23.990000 & 25.450000 & 26.110000 & 26.100000 \\
# Fuzzy - ICM_150_100_150 & 27.360000 & 25.100000 & 26.740000 & 27.340000 & 27.470000 \\
# \bottomrule
# \end{tabular}

# %%
# Configurar el estilo y colores contrastantes
sns.set_palette("tab10")  # Utilizar una paleta de colores de Seaborn
#plt.style.use('seaborn')

# Crear un gráfico de dispersión
plt.figure(figsize=(10, 6))
for columna in nuevo_df.columns:
    plt.scatter(nuevo_df.index, nuevo_df[columna], label=columna)

# Configurar etiquetas y título

plt.ylabel('Score')
plt.title('Embedding functions analysis')
plt.xticks(rotation='vertical')  # Rotar las etiquetas del eje X en vertical
plt.legend()

# Mostrar el gráfico
plt.tight_layout()  # Ajustar el diseño
plt.savefig('./results/img/embedding_analysis.png', dpi=300)


plt.show()

# %% [markdown]
# # Specification and generalization fucntions analysis

# %%
# Definir los índices de los grupos
indices_grupo1 = list(range(0, 11)) + list(range(33, 44)) + list(range(66, 77))+ list(range(99, 110))+ list(range(132, 143))
indices_grupo2 = list(range(11, 22)) + list(range(44, 55)) + list(range(77, 88))+ list(range(110, 121))+ list(range(143, 154))
indices_grupo3 = list(range(22, 33)) + list(range(55, 66)) + list(range(88, 99))+ list(range(121, 132))+ list(range(154, 165))

# Crear los grupos
grupo1 = list(analysis_df.iloc[indices_grupo1])
grupo2 = list(analysis_df.iloc[indices_grupo2])
grupo3 = list(analysis_df.iloc[indices_grupo3])

# Crear el DataFrame
nombres_filas = [
'Sum of Vectors - Cosine',
'Sum of Vectors - Euclidean',
'Sum of Vectors - Dot',
'Sum of Vectors - ICM_100_100_150',
'Sum of Vectors - ICM_150_050_150',
'Sum of Vectors - ICM_175_075_15',
'Sum of Vectors - ICM_150_050_100',
'Sum of Vectors - ICM_150_050_200',
'Sum of Vectors - ICM_050_150_150',
'Sum of Vectors - ICM_050_150_050',
'Sum of Vectors - ICM_150_100_150',
'Average - Cosine',
'Average - Euclidean',
'Average - Dot',
'Average - ICM_100_100_150',
'Average - ICM_150_050_150',
'Average - ICM_175_075_15',
'Average - ICM_150_050_100',
'Average - ICM_150_050_200',
'Average - ICM_050_150_150',
'Average - ICM_050_150_050',
'Average - ICM_150_100_150',
'F_joint - Cosine',
'F_joint - Euclidean',
'F_joint - Dot',
'F_joint - ICM_100_100_150',
'F_joint - ICM_150_050_150',
'F_joint - ICM_175_075_15',
'F_joint - ICM_150_050_100',
'F_joint - ICM_150_050_200',
'F_joint - ICM_050_150_150',
'F_joint - ICM_050_150_050',
'F_joint - ICM_150_100_150',
'F_ind - Cosine',
'F_ind - Euclidean',
'F_ind - Dot',
'F_ind - ICM_100_100_150',
'F_ind - ICM_150_050_150',
'F_ind - ICM_175_075_15',
'F_ind - ICM_150_050_100',
'F_ind - ICM_150_050_200',
'F_ind - ICM_050_150_150',
'F_ind - ICM_050_150_050',
'F_ind - ICM_150_100_150',
'F_inf - Cosine',
'F_inf - Euclidean',
'F_inf - Dot',
'F_inf - ICM_100_100_150',
'F_inf - ICM_150_050_150',
'F_inf - ICM_175_075_15',
'F_inf - ICM_150_050_100',
'F_inf - ICM_150_050_200',
'F_inf - ICM_050_150_150',
'F_inf - ICM_050_150_050',
'F_inf - ICM_150_100_150'
    ]

data = {'Algebraic': grupo1, 'Information': grupo2, 'Fuzzy': grupo3}
nuevo_df = pd.DataFrame(data, index=nombres_filas)

latex_table = nuevo_df.to_latex()
print(latex_table)
# Out:
# \begin{tabular}{lrrr}
# \toprule
#  & Algebraic & Information & Fuzzy \\
# \midrule
# Sum of Vectors - Cosine & 20.990000 & 21.220000 & 24.180000 \\
# Sum of Vectors - Euclidean & 17.700000 & 14.320000 & 17.680000 \\
# Sum of Vectors - Dot & 23.630000 & 23.600000 & 26.550000 \\
# Sum of Vectors - ICM_100_100_150 & 24.720000 & 25.040000 & 28.620000 \\
# Sum of Vectors - ICM_150_050_150 & 25.460000 & 24.340000 & 27.280000 \\
# Sum of Vectors - ICM_175_075_15 & 24.140000 & 24.120000 & 26.800000 \\
# Sum of Vectors - ICM_150_050_100 & 24.110000 & 23.790000 & 26.490000 \\
# Sum of Vectors - ICM_150_050_200 & 24.000000 & 22.380000 & 25.650000 \\
# Sum of Vectors - ICM_050_150_150 & 23.900000 & 24.760000 & 27.870000 \\
# Sum of Vectors - ICM_050_150_050 & 23.500000 & 21.940000 & 26.160000 \\
# Sum of Vectors - ICM_150_100_150 & 24.170000 & 24.060000 & 27.360000 \\
# Average - Cosine & 21.830000 & 22.970000 & 24.900000 \\
# Average - Euclidean & 16.690000 & 12.960000 & 16.320000 \\
# Average - Dot & 20.710000 & 22.320000 & 24.120000 \\
# Average - ICM_100_100_150 & 22.890000 & 23.560000 & 26.520000 \\
# Average - ICM_150_050_150 & 23.960000 & 23.140000 & 25.310000 \\
# Average - ICM_175_075_15 & 22.510000 & 22.450000 & 24.730000 \\
# Average - ICM_150_050_100 & 22.430000 & 21.690000 & 24.240000 \\
# Average - ICM_150_050_200 & 22.570000 & 21.930000 & 24.690000 \\
# Average - ICM_050_150_150 & 20.060000 & 23.580000 & 25.660000 \\
# Average - ICM_050_150_050 & 20.230000 & 19.990000 & 23.990000 \\
# Average - ICM_150_100_150 & 22.210000 & 22.750000 & 25.100000 \\
# F_joint - Cosine & 21.980000 & 23.360000 & 25.540000 \\
# F_joint - Euclidean & 17.440000 & 13.990000 & 17.370000 \\
# F_joint - Dot & 22.020000 & 23.850000 & 25.580000 \\
# F_joint - ICM_100_100_150 & 24.060000 & 24.870000 & 28.160000 \\
# F_joint - ICM_150_050_150 & 25.200000 & 24.690000 & 26.890000 \\
# F_joint - ICM_175_075_15 & 23.710000 & 24.200000 & 26.400000 \\
# F_joint - ICM_150_050_100 & 23.600000 & 23.310000 & 26.000000 \\
# F_joint - ICM_150_050_200 & 23.420000 & 22.980000 & 26.080000 \\
# F_joint - ICM_050_150_150 & 21.380000 & 24.830000 & 27.220000 \\
# F_joint - ICM_050_150_050 & 21.610000 & 21.630000 & 25.450000 \\
# F_joint - ICM_150_100_150 & 23.490000 & 24.450000 & 26.740000 \\
# F_ind - Cosine & 20.530000 & 21.750000 & 24.390000 \\
# F_ind - Euclidean & 17.070000 & 14.320000 & 17.680000 \\
# F_ind - Dot & 22.580000 & 23.900000 & 26.340000 \\
# F_ind - ICM_100_100_150 & 23.970000 & 25.240000 & 28.650000 \\
# F_ind - ICM_150_050_150 & 25.020000 & 24.690000 & 27.350000 \\
# F_ind - ICM_175_075_15 & 23.470000 & 24.310000 & 26.750000 \\
# F_ind - ICM_150_050_100 & 23.380000 & 23.800000 & 26.420000 \\
# F_ind - ICM_150_050_200 & 23.140000 & 22.690000 & 25.860000 \\
# F_ind - ICM_050_150_150 & 22.430000 & 25.000000 & 27.760000 \\
# F_ind - ICM_050_150_050 & 22.370000 & 22.030000 & 26.110000 \\
# F_ind - ICM_150_100_150 & 23.390000 & 24.490000 & 27.340000 \\
# F_inf - Cosine & 20.910000 & 22.220000 & 24.720000 \\
# F_inf - Euclidean & 17.400000 & 14.320000 & 17.680000 \\
# F_inf - Dot & 22.780000 & 24.230000 & 26.320000 \\
# F_inf - ICM_100_100_150 & 24.380000 & 25.330000 & 28.710000 \\
# F_inf - ICM_150_050_150 & 25.450000 & 25.060000 & 27.450000 \\
# F_inf - ICM_175_075_15 & 23.910000 & 24.680000 & 26.870000 \\
# F_inf - ICM_150_050_100 & 23.800000 & 24.040000 & 26.550000 \\
# F_inf - ICM_150_050_200 & 23.530000 & 23.000000 & 26.170000 \\
# F_inf - ICM_050_150_150 & 22.330000 & 25.190000 & 27.810000 \\
# F_inf - ICM_050_150_050 & 22.370000 & 22.150000 & 26.100000 \\
# F_inf - ICM_150_100_150 & 23.790000 & 24.760000 & 27.470000 \\
# \bottomrule
# \end{tabular}

# %%
# Configurar el estilo y colores contrastantes
sns.set_palette("tab10")  # Utilizar una paleta de colores de Seaborn
#plt.style.use('seaborn-pastel')

# Crear un gráfico de dispersión
plt.figure(figsize=(10, 6))
for columna in nuevo_df.columns:
    plt.scatter(nuevo_df.index, nuevo_df[columna], label=columna)

# Configurar etiquetas y título

plt.ylabel('Score')
plt.title('Specification and generalization functions analysis')
plt.xticks(rotation='vertical')  # Rotar las etiquetas del eje X en vertical
plt.legend()

# Mostrar el gráfico
plt.tight_layout()  # Ajustar el diseño
plt.savefig('./results/img/generalisation_analysis.png', dpi=300)


plt.show()

# %% [markdown]
# # Similarity function analysis

# %%
# Definir los índices de los grupos
indices_grupo1 = list(range(0, 165, 11))
indices_grupo2 = [elem + 1 for elem in indices_grupo1]
indices_grupo3 = [elem + 2 for elem in indices_grupo1]
indices_grupo4 = [elem + 3 for elem in indices_grupo1]
indices_grupo5 = [elem + 4 for elem in indices_grupo1]
indices_grupo6 = [elem + 5 for elem in indices_grupo1]
indices_grupo7 = [elem + 6 for elem in indices_grupo1]
indices_grupo8 = [elem + 7 for elem in indices_grupo1]
indices_grupo9 = [elem + 8 for elem in indices_grupo1]
indices_grupo10 = [elem + 9 for elem in indices_grupo1]
indices_grupo11 = [elem + 10 for elem in indices_grupo1]

# Crear los grupos
grupo1 = list(analysis_df.iloc[indices_grupo1])
grupo2 = list(analysis_df.iloc[indices_grupo2])
grupo3 = list(analysis_df.iloc[indices_grupo3])
grupo4 = list(analysis_df.iloc[indices_grupo4])
grupo5 = list(analysis_df.iloc[indices_grupo5])
grupo6 = list(analysis_df.iloc[indices_grupo6])
grupo7 = list(analysis_df.iloc[indices_grupo7])
grupo8 = list(analysis_df.iloc[indices_grupo8])
grupo9 = list(analysis_df.iloc[indices_grupo9])
grupo10 = list(analysis_df.iloc[indices_grupo10])
grupo11 = list(analysis_df.iloc[indices_grupo11])

# Crear el DataFrame
nombres_filas = [
'Sum of Vectors - Algebraic',
'Sum of Vectors - Information',
'Sum of Vectors - Fuzzy',
'Average - Algebraic',
'Average - Information',
'Average - Fuzzy',
'F_joint - Algebraic',
'F_joint - Information',
'F_joint - Fuzzy',
'F_ind - Algebraic',
'F_ind - Information',
'F_ind - Fuzzy',
'F_inf - Algebraic',
'F_inf - Information',
'F_inf - Fuzzy'
    ]

data = {'Cosine': grupo1, 'Euclidean': grupo2, 'Dot': grupo3, 'ICM_100_100_150': grupo4, 'ICM_150_050_150': grupo5, 'ICM_175_075_15': grupo6, 'ICM_150_050_100': grupo7, 'ICM_150_050_200': grupo8, 'ICM_050_150_150': grupo9, 'ICM_050_150_050': grupo10, 'ICM_150_100_150': grupo11}
nuevo_df = pd.DataFrame(data, index=nombres_filas)

latex_table = nuevo_df.to_latex()
print(latex_table)
# Out:
# \begin{tabular}{lrrrrrrrrrrr}
# \toprule
#  & Cosine & Euclidean & Dot & ICM_100_100_150 & ICM_150_050_150 & ICM_175_075_15 & ICM_150_050_100 & ICM_150_050_200 & ICM_050_150_150 & ICM_050_150_050 & ICM_150_100_150 \\
# \midrule
# Sum of Vectors - Algebraic & 20.990000 & 17.700000 & 23.630000 & 24.720000 & 25.460000 & 24.140000 & 24.110000 & 24.000000 & 23.900000 & 23.500000 & 24.170000 \\
# Sum of Vectors - Information & 21.220000 & 14.320000 & 23.600000 & 25.040000 & 24.340000 & 24.120000 & 23.790000 & 22.380000 & 24.760000 & 21.940000 & 24.060000 \\
# Sum of Vectors - Fuzzy & 24.180000 & 17.680000 & 26.550000 & 28.620000 & 27.280000 & 26.800000 & 26.490000 & 25.650000 & 27.870000 & 26.160000 & 27.360000 \\
# Average - Algebraic & 21.830000 & 16.690000 & 20.710000 & 22.890000 & 23.960000 & 22.510000 & 22.430000 & 22.570000 & 20.060000 & 20.230000 & 22.210000 \\
# Average - Information & 22.970000 & 12.960000 & 22.320000 & 23.560000 & 23.140000 & 22.450000 & 21.690000 & 21.930000 & 23.580000 & 19.990000 & 22.750000 \\
# Average - Fuzzy & 24.900000 & 16.320000 & 24.120000 & 26.520000 & 25.310000 & 24.730000 & 24.240000 & 24.690000 & 25.660000 & 23.990000 & 25.100000 \\
# F_joint - Algebraic & 21.980000 & 17.440000 & 22.020000 & 24.060000 & 25.200000 & 23.710000 & 23.600000 & 23.420000 & 21.380000 & 21.610000 & 23.490000 \\
# F_joint - Information & 23.360000 & 13.990000 & 23.850000 & 24.870000 & 24.690000 & 24.200000 & 23.310000 & 22.980000 & 24.830000 & 21.630000 & 24.450000 \\
# F_joint - Fuzzy & 25.540000 & 17.370000 & 25.580000 & 28.160000 & 26.890000 & 26.400000 & 26.000000 & 26.080000 & 27.220000 & 25.450000 & 26.740000 \\
# F_ind - Algebraic & 20.530000 & 17.070000 & 22.580000 & 23.970000 & 25.020000 & 23.470000 & 23.380000 & 23.140000 & 22.430000 & 22.370000 & 23.390000 \\
# F_ind - Information & 21.750000 & 14.320000 & 23.900000 & 25.240000 & 24.690000 & 24.310000 & 23.800000 & 22.690000 & 25.000000 & 22.030000 & 24.490000 \\
# F_ind - Fuzzy & 24.390000 & 17.680000 & 26.340000 & 28.650000 & 27.350000 & 26.750000 & 26.420000 & 25.860000 & 27.760000 & 26.110000 & 27.340000 \\
# F_inf - Algebraic & 20.910000 & 17.400000 & 22.780000 & 24.380000 & 25.450000 & 23.910000 & 23.800000 & 23.530000 & 22.330000 & 22.370000 & 23.790000 \\
# F_inf - Information & 22.220000 & 14.320000 & 24.230000 & 25.330000 & 25.060000 & 24.680000 & 24.040000 & 23.000000 & 25.190000 & 22.150000 & 24.760000 \\
# F_inf - Fuzzy & 24.720000 & 17.680000 & 26.320000 & 28.710000 & 27.450000 & 26.870000 & 26.550000 & 26.170000 & 27.810000 & 26.100000 & 27.470000 \\
# \bottomrule
# \end{tabular}

# %%
# Configurar el estilo y colores contrastantes
sns.set_palette("tab10")  # Utilizar una paleta de colores de Seaborn
#plt.style.use('seaborn-pastel')

# Crear un gráfico de dispersión
plt.figure(figsize=(10, 6))
for columna in nuevo_df.columns:
    plt.scatter(nuevo_df.index, nuevo_df[columna], label=columna)

# Configurar etiquetas y título

plt.ylabel('Score')
plt.title('Similarity functions analysis')
plt.xticks(rotation='vertical')  # Rotar las etiquetas del eje X en vertical
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Mostrar el gráfico
plt.tight_layout()  # Ajustar el diseño
plt.savefig('./results/img/similarity_analysis.png', dpi=300)


plt.show()

# %% [markdown]
# # Star charts

# %%
print('Progress: 0%')
q = 0
# Define el número de cuadrantes
num_cuadrantes = 12
# Asignar colores a los cuadrantes
colors = ['coral', 'coral', 'coral', 'coral', 'aquamarine', 'aquamarine', 'aquamarine', 'aquamarine', 'aquamarine', 'steelblue', 'steelblue', 'steelblue']

theta=['Constraint 1 - Injectivity', 'Constraint 2 - Zero informativeness', 'Constraint 3 - Infinite informativeness', 'Constraint 4 - Upper and lower bounds',
          'Constraint 5 - Commutativity', 'Constraint 6 - Associativity', 'Constraint 7 - Distributiveness', 'Constraint 8 - Idempotency',
          'Constraint 9 - Identity', 'Constraint 10 - Similarity monotonicity', 'Constraint 11 - Self-similarity', 'Constraint 12 - Asymmetricity']


for i in range(165):
  q += 1
  df = pd.DataFrame(dict(
      r=normalized_results.iloc[:12, i],
      theta=['Constraint 1 - Injectivity', 'Constraint 2 - Zero informativeness', 'Constraint 3 - Infinite informativeness', 'Constraint 4 - Upper and lower bounds',
          'Constraint 5 - Commutativity', 'Constraint 6 - Associativity', 'Constraint 7 - Distributiveness', 'Constraint 8 - Idempotency',
          'Constraint 9 - Identity', 'Constraint 10 - Similarity monotonicity', 'Constraint 11 - Self-similarity', 'Constraint 12 - Asymmetricity']))
   # Crear el gráfico polar
  fig = go.Figure()

  for pp in range(num_cuadrantes):
      r1_data = df.iloc[pp]['r']
      theta_data = df.iloc[pp]['theta']
      # Agregar la serie 1 al gráfico
      fig.add_trace(go.Barpolar(
          r=[r1_data, 0],  # Los datos de la serie 1 y un valor cero para el centro del gráfico
          theta=[theta_data, theta_data],  # Las coordenadas angulares
          name='Serie 1',
          marker_color=colors[pp % len(colors)],  # Selecciona un color para el cuadrante
          showlegend=False  # No mostrar la leyenda para cada cuadrante
      ))

  # Personaliza el diseño del gráfico polar
  fig.update_layout(
      polar=dict(
          radialaxis=dict(range=[0, 1]),
          angularaxis=dict(direction="clockwise", showline=False)
      ),
      title=normalized_results.columns[i] + ' - Aggregated results',
      title_x=0.5,
      title_y=0.99
  )
  fig.write_image('./results/img/' + normalized_results.columns[i] + ' - Sequences results.png', width=1500, height=1080)


  df = pd.DataFrame(dict(
      r=normalized_results.iloc[12:24, i],
      theta=['Constraint 1 - Injectivity', 'Constraint 2 - Zero informativeness', 'Constraint 3 - Infinite informativeness', 'Constraint 4 - Upper and lower bounds',
          'Constraint 5 - Commutativity', 'Constraint 6 - Associativity', 'Constraint 7 - Distributiveness', 'Constraint 8 - Idempotency',
          'Constraint 9 - Identity', 'Constraint 10 - Similarity monotonicity', 'Constraint 11 - Self-similarity', 'Constraint 12 - Asymmetricity']))
   # Crear el gráfico polar
  fig = go.Figure()

  for pp in range(num_cuadrantes):
      r1_data = df.iloc[pp]['r']
      theta_data = df.iloc[pp]['theta']
      # Agregar la serie 1 al gráfico
      fig.add_trace(go.Barpolar(
          r=[r1_data, 0],  # Los datos de la serie 1 y un valor cero para el centro del gráfico
          theta=[theta_data, theta_data],  # Las coordenadas angulares
          name='Serie 1',
          marker_color=colors[pp % len(colors)],  # Selecciona un color para el cuadrante
          showlegend=False  # No mostrar la leyenda para cada cuadrante
      ))

  # Personaliza el diseño del gráfico polar
  fig.update_layout(
      polar=dict(
          radialaxis=dict(range=[0, 1]),
          angularaxis=dict(direction="clockwise", showline=False)
      ),
      title=normalized_results.columns[i] + ' - Aggregated results',
      title_x=0.5,
      title_y=0.99
  )
  fig.write_image('./results/img/star/' + normalized_results.columns[i] + ' - Ancestors results.png', width=1500, height=1080)


  df = pd.DataFrame(dict(
      r=normalized_results.iloc[24:36, i],
      theta=['Constraint 1 - Injectivity', 'Constraint 2 - Zero informativeness', 'Constraint 3 - Infinite informativeness', 'Constraint 4 - Upper and lower bounds',
          'Constraint 5 - Commutativity', 'Constraint 6 - Associativity', 'Constraint 7 - Distributiveness', 'Constraint 8 - Idempotency',
          'Constraint 9 - Identity', 'Constraint 10 - Similarity monotonicity', 'Constraint 11 - Self-similarity', 'Constraint 12 - Asymmetricity']))
   # Crear el gráfico polar
  fig = go.Figure()

  for pp in range(num_cuadrantes):
      r1_data = df.iloc[pp]['r']
      theta_data = df.iloc[pp]['theta']
      # Agregar la serie 1 al gráfico
      fig.add_trace(go.Barpolar(
          r=[r1_data, 0],  # Los datos de la serie 1 y un valor cero para el centro del gráfico
          theta=[theta_data, theta_data],  # Las coordenadas angulares
          name='Serie 1',
          marker_color=colors[pp % len(colors)],  # Selecciona un color para el cuadrante
          showlegend=False  # No mostrar la leyenda para cada cuadrante
      ))

  # Personaliza el diseño del gráfico polar
  fig.update_layout(
      polar=dict(
          radialaxis=dict(range=[0, 1]),
          angularaxis=dict(direction="clockwise", showline=False)
      ),
      title=normalized_results.columns[i] + ' - Aggregated results',
      title_x=0.5,
      title_y=0.99
  )
  fig.write_image('./results/img/' + normalized_results.columns[i] + ' - Summaries results.png', width=1500, height=1080)


  df = pd.DataFrame(dict(
      r=(normalized_results.iloc[:12, i] + normalized_results.iloc[12:24, i] + normalized_results.iloc[24:36, i]) / 3,
      theta=['Constraint 1 - Injectivity', 'Constraint 2 - Zero informativeness', 'Constraint 3 - Infinite informativeness', 'Constraint 4 - Upper and lower bounds',
          'Constraint 5 - Commutativity', 'Constraint 6 - Associativity', 'Constraint 7 - Distributiveness', 'Constraint 8 - Idempotency',
          'Constraint 9 - Identity', 'Constraint 10 - Similarity monotonicity', 'Constraint 11 - Self-similarity', 'Constraint 12 - Asymmetricity']))

  # Crear el gráfico polar
  fig = go.Figure()

  for pp in range(num_cuadrantes):
      r1_data = df.iloc[pp]['r']
      theta_data = df.iloc[pp]['theta']
      # Agregar la serie 1 al gráfico
      fig.add_trace(go.Barpolar(
          r=[r1_data, 0],  # Los datos de la serie 1 y un valor cero para el centro del gráfico
          theta=[theta_data, theta_data],  # Las coordenadas angulares
          name='Serie 1',
          marker_color=colors[pp % len(colors)],  # Selecciona un color para el cuadrante
          showlegend=False  # No mostrar la leyenda para cada cuadrante
      ))

  # Personaliza el diseño del gráfico polar
  fig.update_layout(
      polar=dict(
          radialaxis=dict(range=[0, 1]),
          angularaxis=dict(direction="clockwise", showline=False)
      ),
      title=normalized_results.columns[i] + ' - Aggregated results',
      title_x=0.5,
      title_y=0.99
  )
  fig.write_image('./results/img/star/' + normalized_results.columns[i] + ' - Aggregated results.png', width=1500, height=1080)
  #fig.show()

  if q % 8 == 0:
   print('Progress: ' + str(round(q*100/165,2)) + '%')
print('Progress: 100%!')
# Out:
# Progress: 0%
# Progress: 4.85%
# Progress: 9.7%
# Progress: 14.55%
# Progress: 19.39%
# Progress: 24.24%
# Progress: 29.09%
# Progress: 33.94%
# Progress: 38.79%
# Progress: 43.64%
# Progress: 48.48%
# Progress: 53.33%
# Progress: 58.18%
# Progress: 63.03%
# Progress: 67.88%
# Progress: 72.73%
# Progress: 77.58%
# Progress: 82.42%
# Progress: 87.27%
# Progress: 92.12%
# Progress: 96.97%
# Progress: 100%!

# %%
print('Progress: 0%')
q = 0
# Define el número de cuadrantes
num_cuadrantes = 20
# Asignar colores a los cuadrantes
colors = ['coral', 'coral', 'coral', 'coral', 'coral',
          'coral', 'coral', 'coral', 'coral', 'coral',
          'coral', 'coral', 'coral', 'coral', 'coral',
          'coral', 'coral', 'coral', 'coral', 'coral',
          'aquamarine', 'aquamarine', 'aquamarine', 'aquamarine', 'aquamarine',
          'aquamarine', 'aquamarine', 'aquamarine', 'aquamarine', 'aquamarine',
          'aquamarine', 'aquamarine', 'aquamarine', 'aquamarine', 'aquamarine',
          'aquamarine', 'aquamarine', 'aquamarine', 'aquamarine', 'aquamarine',
          'steelblue', 'steelblue', 'steelblue', 'steelblue', 'steelblue',
          'steelblue', 'steelblue', 'steelblue', 'steelblue', 'steelblue',
          'steelblue', 'steelblue', 'steelblue', 'steelblue', 'steelblue',
          'steelblue', 'steelblue', 'steelblue', 'steelblue', 'steelblue']

theta=['Test 1 - Sequences', 'Test 2 - Sequences', 'Test 3 - Sequences', 'Test 4 - Sequences', 'Test 5 - Sequences',
             'Test 6 - Sequences', 'Test 7 - Sequences', 'Test 8 - Sequences', 'Test 9 - Sequences', 'Test 10 - Sequences',
             'Test 11 - Sequences', 'Test 12 - Sequences', 'Test 13 - Sequences', 'Test 14 - Sequences', 'Test 15 - Sequences',
             'Test 16 - Sequences', 'Test 17 - Sequences', 'Test 18 - Sequences', 'Test 19 - Sequences', 'Test 20 - Sequences',
             'Test 1 - Ancestors', 'Test 2 - Ancestors', 'Test 3 - Ancestors', 'Test 4 - Ancestors', 'Test 5 - Ancestors',
             'Test 6 - Ancestors', 'Test 7 - Ancestors', 'Test 8 - Ancestors', 'Test 9 - Ancestors', 'Test 10 - Ancestors',
             'Test 11 - Ancestors', 'Test 12 - Ancestors', 'Test 13 - Ancestors', 'Test 14 - Ancestors', 'Test 15 - Ancestors',
             'Test 16 - Ancestors', 'Test 17 - Ancestors', 'Test 21 - Ancestors', 'Test 22 - Ancestors', 'Test 23 - Ancestors',
             'Test 1 - Summaries', 'Test 2 - Summaries', 'Test 3 - Summaries', 'Test 4 - Summaries', 'Test 5 - Summaries',
             'Test 6 - Summaries', 'Test 7 - Summaries', 'Test 8 - Summaries', 'Test 9 - Summaries', 'Test 10 - Summaries',
             'Test 11 - Summaries', 'Test 12 - Summaries', 'Test 13 - Summaries', 'Test 14 - Summaries', 'Test 15 - Summaries',
             'Test 16 - Summaries', 'Test 17 - Summaries', 'Test 24 - Summaries', 'Test 25 - Summaries', 'Test 26 - Summaries']


for i in range(165):
  q += 1
  df = pd.DataFrame(dict(
      r=row_normalized_results.iloc[:20, i],
      theta=['Test 1 - Sequences', 'Test 2 - Sequences', 'Test 3 - Sequences', 'Test 4 - Sequences', 'Test 5 - Sequences',
             'Test 6 - Sequences', 'Test 7 - Sequences', 'Test 8 - Sequences', 'Test 9 - Sequences', 'Test 10 - Sequences',
             'Test 11 - Sequences', 'Test 12 - Sequences', 'Test 13 - Sequences', 'Test 14 - Sequences', 'Test 15 - Sequences',
             'Test 16 - Sequences', 'Test 17 - Sequences', 'Test 18 - Sequences', 'Test 19 - Sequences', 'Test 20 - Sequences']))
   # Crear el gráfico polar
  fig = go.Figure()

  for pp in range(num_cuadrantes):
      r1_data = df.iloc[pp]['r']
      theta_data = df.iloc[pp]['theta']
      # Agregar la serie 1 al gráfico
      fig.add_trace(go.Barpolar(
          r=[r1_data, 0],  # Los datos de la serie 1 y un valor cero para el centro del gráfico
          theta=[theta_data, theta_data],  # Las coordenadas angulares
          name='Serie 1',
          marker_color=colors[pp % len(colors)],  # Selecciona un color para el cuadrante
          showlegend=False  # No mostrar la leyenda para cada cuadrante
      ))

  # Personaliza el diseño del gráfico polar
  fig.update_layout(
      polar=dict(
          radialaxis=dict(range=[0, 1]),
          angularaxis=dict(direction="clockwise", showline=False)
      ),
      title=normalized_results.columns[i] + ' - Sequences results',
      title_x=0.5,
      title_y=0.99
  )
  fig.write_image('./results/img/star_tests/' + normalized_results.columns[i] + ' - Sequences results.png', width=1500, height=1080)


  df = pd.DataFrame(dict(
      r=row_normalized_results.iloc[20:40, i],
      theta=['Test 1 - Ancestors', 'Test 2 - Ancestors', 'Test 3 - Ancestors', 'Test 4 - Ancestors', 'Test 5 - Ancestors',
             'Test 6 - Ancestors', 'Test 7 - Ancestors', 'Test 8 - Ancestors', 'Test 9 - Ancestors', 'Test 10 - Ancestors',
             'Test 11 - Ancestors', 'Test 12 - Ancestors', 'Test 13 - Ancestors', 'Test 14 - Ancestors', 'Test 15 - Ancestors',
             'Test 16 - Ancestors', 'Test 17 - Ancestors', 'Test 21 - Ancestors', 'Test 22 - Ancestors', 'Test 23 - Ancestors']))
   # Crear el gráfico polar
  fig = go.Figure()

  for pp in range(num_cuadrantes):
      r1_data = df.iloc[pp]['r']
      theta_data = df.iloc[pp]['theta']
      # Agregar la serie 1 al gráfico
      fig.add_trace(go.Barpolar(
          r=[r1_data, 0],  # Los datos de la serie 1 y un valor cero para el centro del gráfico
          theta=[theta_data, theta_data],  # Las coordenadas angulares
          name='Serie 1',
          marker_color=colors[pp % len(colors)],  # Selecciona un color para el cuadrante
          showlegend=False  # No mostrar la leyenda para cada cuadrante
      ))

  # Personaliza el diseño del gráfico polar
  fig.update_layout(
      polar=dict(
          radialaxis=dict(range=[0, 1]),
          angularaxis=dict(direction="clockwise", showline=False)
      ),
      title=normalized_results.columns[i] + ' - Ancestors results',
      title_x=0.5,
      title_y=0.99
  )
  fig.write_image('./results/img/star_tests/' + normalized_results.columns[i] + ' - Ancestors results.png', width=1500, height=1080)


  df = pd.DataFrame(dict(
      r=row_normalized_results.iloc[40:60, i],
      theta=['Test 1 - Summaries', 'Test 2 - Summaries', 'Test 3 - Summaries', 'Test 4 - Summaries', 'Test 5 - Summaries',
             'Test 6 - Summaries', 'Test 7 - Summaries', 'Test 8 - Summaries', 'Test 9 - Summaries', 'Test 10 - Summaries',
             'Test 11 - Summaries', 'Test 12 - Summaries', 'Test 13 - Summaries', 'Test 14 - Summaries', 'Test 15 - Summaries',
             'Test 16 - Summaries', 'Test 17 - Summaries', 'Test 24 - Summaries', 'Test 25 - Summaries', 'Test 26 - Summaries']))
   # Crear el gráfico polar
  fig = go.Figure()

  for pp in range(num_cuadrantes):
      r1_data = df.iloc[pp]['r']
      theta_data = df.iloc[pp]['theta']
      # Agregar la serie 1 al gráfico
      fig.add_trace(go.Barpolar(
          r=[r1_data, 0],  # Los datos de la serie 1 y un valor cero para el centro del gráfico
          theta=[theta_data, theta_data],  # Las coordenadas angulares
          name='Serie 1',
          marker_color=colors[pp % len(colors)],  # Selecciona un color para el cuadrante
          showlegend=False  # No mostrar la leyenda para cada cuadrante
      ))

  # Personaliza el diseño del gráfico polar
  fig.update_layout(
      polar=dict(
          radialaxis=dict(range=[0, 1]),
          angularaxis=dict(direction="clockwise", showline=False)
      ),
      title=normalized_results.columns[i] + ' - Summaries results',
      title_x=0.5,
      title_y=0.99
  )
  fig.write_image('./results/img/star_tests/' + normalized_results.columns[i] + ' - Summaries results.png', width=1500, height=1080)


  df = pd.DataFrame(dict(
      r=row_normalized_results.iloc[:, i],
      theta=['Test 1 - Sequences', 'Test 2 - Sequences', 'Test 3 - Sequences', 'Test 4 - Sequences', 'Test 5 - Sequences',
             'Test 6 - Sequences', 'Test 7 - Sequences', 'Test 8 - Sequences', 'Test 9 - Sequences', 'Test 10 - Sequences',
             'Test 11 - Sequences', 'Test 12 - Sequences', 'Test 13 - Sequences', 'Test 14 - Sequences', 'Test 15 - Sequences',
             'Test 16 - Sequences', 'Test 17 - Sequences', 'Test 18 - Sequences', 'Test 19 - Sequences', 'Test 20 - Sequences',
             'Test 1 - Ancestors', 'Test 2 - Ancestors', 'Test 3 - Ancestors', 'Test 4 - Ancestors', 'Test 5 - Ancestors',
             'Test 6 - Ancestors', 'Test 7 - Ancestors', 'Test 8 - Ancestors', 'Test 9 - Ancestors', 'Test 10 - Ancestors',
             'Test 11 - Ancestors', 'Test 12 - Ancestors', 'Test 13 - Ancestors', 'Test 14 - Ancestors', 'Test 15 - Ancestors',
             'Test 16 - Ancestors', 'Test 17 - Ancestors', 'Test 21 - Ancestors', 'Test 22 - Ancestors', 'Test 23 - Ancestors',
             'Test 1 - Summaries', 'Test 2 - Summaries', 'Test 3 - Summaries', 'Test 4 - Summaries', 'Test 5 - Summaries',
             'Test 6 - Summaries', 'Test 7 - Summaries', 'Test 8 - Summaries', 'Test 9 - Summaries', 'Test 10 - Summaries',
             'Test 11 - Summaries', 'Test 12 - Summaries', 'Test 13 - Summaries', 'Test 14 - Summaries', 'Test 15 - Summaries',
             'Test 16 - Summaries', 'Test 17 - Summaries', 'Test 24 - Summaries', 'Test 25 - Summaries', 'Test 26 - Summaries']))

  # Crear el gráfico polar
  fig = go.Figure()

  for pp in range(60):
      r1_data = df.iloc[pp]['r']
      theta_data = df.iloc[pp]['theta']
      # Agregar la serie 1 al gráfico
      fig.add_trace(go.Barpolar(
          r=[r1_data, 0],  # Los datos de la serie 1 y un valor cero para el centro del gráfico
          theta=[theta_data, theta_data],  # Las coordenadas angulares
          name='Serie 1',
          marker_color=colors[pp % len(colors)],  # Selecciona un color para el cuadrante
          showlegend=False  # No mostrar la leyenda para cada cuadrante
      ))

  # Personaliza el diseño del gráfico polar
  fig.update_layout(
      polar=dict(
          radialaxis=dict(range=[0, 1]),
          angularaxis=dict(direction="clockwise", showline=False)
      ),
      title=normalized_results.columns[i] + ' - Aggregated results',
      title_x=0.5,
      title_y=0.99
  )
  fig.write_image('./results/img/star_tests/' + normalized_results.columns[i] + ' - Aggregated results.png', width=1500, height=1080)
  #fig.show()

  if q % 8 == 0:
   print('Progress: ' + str(round(q*100/165,2)) + '%')
print('Progress: 100%!')
# Out:
# Progress: 0%
# Progress: 4.85%
# Progress: 9.7%
# Progress: 14.55%
# Progress: 19.39%
# Progress: 24.24%
# Progress: 29.09%
# Progress: 33.94%
# Progress: 38.79%
# Progress: 43.64%
# Progress: 48.48%
# Progress: 53.33%
# Progress: 58.18%
# Progress: 63.03%
# Progress: 67.88%
# Progress: 72.73%
# Progress: 77.58%
# Progress: 82.42%
# Progress: 87.27%
# Progress: 92.12%
# Progress: 96.97%
# Progress: 100%!
